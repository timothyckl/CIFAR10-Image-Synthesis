# %% [markdown]
# # Experiment 1: Conditional DCGAN with Instance Normalization

# %%
# !pip install tensorflow-addons pandas matplotlib seaborn
# Out:
# Requirement already satisfied: tensorflow-addons in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (0.19.0)
# Requirement already satisfied: pandas in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (3.6.3)
# Requirement already satisfied: seaborn in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (0.12.2)
# Requirement already satisfied: typeguard>=2.7 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: packaging in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from tensorflow-addons) (23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\p2106911\.conda\envs\gpu_env\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import os
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

from IPython import display
from tensorflow.data import Dataset

from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Conv2DTranspose, Embedding, Reshape, Flatten, Dropout, BatchNormalization, ReLU, LeakyReLU, MaxPooling2D, Concatenate
from tensorflow_addons.layers import InstanceNormalization

from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import Callback
from tensorflow.keras.utils import plot_model
# from utils import FrechetInceptionDistance

import warnings
warnings.filterwarnings('ignore')

# %%
sns.set(rc={'figure.dpi': 120})
sns.set_style('whitegrid')

# %%
# set gpu memory growth
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# set random seed
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# ## Load Dataset

# %%
FILE_PATH = '..\data\cifar10.tfrecords'
dataset = Dataset.load(FILE_PATH)
print(dataset.element_spec)
# Out:
# (TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.uint8, name=None))

# %% [markdown]
# ## Defining Generator

# %%
def create_generator(latent_dim):
    # foundation for label embeedded input
    label_input = Input(shape=(1,), name='label_input')
    label_embedding = Embedding(10, 10, name='label_embedding')(label_input)
    
    # linear activation
    label_embedding = Dense(4 * 4, name='label_dense')(label_embedding)

    # reshape to additional channel
    label_embedding = Reshape((4, 4, 1), name='label_reshape')(label_embedding)
    assert label_embedding.shape == (None, 4, 4, 1)

    # foundation for 4x4 image input
    noise_input = Input(shape=(latent_dim,), name='noise_input')
    noise_dense = Dense(4 * 4 * 128, name='noise_dense')(noise_input)
    noise_dense = ReLU(name='noise_relu')(noise_dense)
    noise_reshape = Reshape((4, 4, 128), name='noise_reshape')(noise_dense)
    assert noise_reshape.shape == (None, 4, 4, 128)

    # concatenate label embedding and image to produce 129-channel output
    concat = keras.layers.Concatenate(name='concatenate')([noise_reshape, label_embedding])
    assert concat.shape == (None, 4, 4, 129)

    # upsample to 8x8
    conv1 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', name='conv1')(concat)
    assert conv1.shape == (None, 8, 8, 128)
    conv1 = InstanceNormalization(name='conv1_norm')(conv1)
    conv1 = ReLU(name='conv1_relu')(conv1)

    # upsample to 16x16
    conv2 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', name='conv2')(conv1)
    assert conv2.shape == (None, 16, 16, 128)
    conv2 = InstanceNormalization(name='conv2_norm')(conv2)
    conv2 = ReLU(name='conv2_relu')(conv2)

    # upsample to 32x32
    conv3 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', name='conv3')(conv2)
    assert conv3.shape == (None, 32, 32, 128)
    conv3 = InstanceNormalization(name='conv3_norm')(conv3)
    conv3 = ReLU(name='conv3_relu')(conv3)

    # output 32x32x3
    output = Conv2D(3, (3, 3), activation='tanh', padding='same', name='output')(conv3)
    assert output.shape == (None, 32, 32, 3)

    model = Model(inputs=[noise_input, label_input], outputs=output, name='generator')

    return model

# %%
create_generator(latent_dim=128).summary()
# Out:
# Model: "generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  noise_input (InputLayer)       [(None, 128)]        0           []
#
#  label_input (InputLayer)       [(None, 1)]          0           []
#
#  noise_dense (Dense)            (None, 2048)         264192      ['noise_input[0][0]']
#
#  label_embedding (Embedding)    (None, 1, 10)        100         ['label_input[0][0]']
#
#  noise_relu (ReLU)              (None, 2048)         0           ['noise_dense[0][0]']
#
#  label_dense (Dense)            (None, 1, 16)        176         ['label_embedding[0][0]']
#
#  noise_reshape (Reshape)        (None, 4, 4, 128)    0           ['noise_relu[0][0]']
#
#  label_reshape (Reshape)        (None, 4, 4, 1)      0           ['label_dense[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 129)    0           ['noise_reshape[0][0]',
#                                                                   'label_reshape[0][0]']
#
#  conv1 (Conv2DTranspose)        (None, 8, 8, 128)    264320      ['concatenate[0][0]']
#
#  conv1_norm (InstanceNormalizat  (None, 8, 8, 128)   256         ['conv1[0][0]']
#  ion)
#
#  conv1_relu (ReLU)              (None, 8, 8, 128)    0           ['conv1_norm[0][0]']
#
#  conv2 (Conv2DTranspose)        (None, 16, 16, 128)  262272      ['conv1_relu[0][0]']
#
#  conv2_norm (InstanceNormalizat  (None, 16, 16, 128)  256        ['conv2[0][0]']
#  ion)
#
#  conv2_relu (ReLU)              (None, 16, 16, 128)  0           ['conv2_norm[0][0]']
#
#  conv3 (Conv2DTranspose)        (None, 32, 32, 128)  262272      ['conv2_relu[0][0]']
#
#  conv3_norm (InstanceNormalizat  (None, 32, 32, 128)  256        ['conv3[0][0]']
#  ion)
#
#  conv3_relu (ReLU)              (None, 32, 32, 128)  0           ['conv3_norm[0][0]']
#
#  output (Conv2D)                (None, 32, 32, 3)    3459        ['conv3_relu[0][0]']
#
# ==================================================================================================
# Total params: 1,057,559
# Trainable params: 1,057,559
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# visualize generator
# plot_model(generator, show_shapes=True, to_file='images\model_architecture\Conditional_DCGAN\generator.png')
# generator_img = mpimg.imread('images\model_architecture\Conditional_DCGAN\generator.png')

# plt.figure(figsize=(20, 20))
# imgplot = plt.imshow(generator_img)
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Defining Discriminator

# %%
def create_discriminator():
    # foundation for label embeedded input
    label_input = Input(shape=(1,), name='label_input')
    label_embedding = Embedding(10, 10, name='label_embedding')(label_input)
    
    # linear activation
    label_embedding = Dense(32 * 32, name='label_dense')(label_embedding)
    
    # reshape to additional channel
    label_embedding = Reshape((32, 32, 1), name='label_reshape')(label_embedding)
    assert label_embedding.shape == (None, 32, 32, 1)

    # foundation for 32x32 image input
    image_input = Input(shape=(32, 32, 3), name='image_input')

    # concatenate label embedding and image to produce 129-channel input
    concat = keras.layers.Concatenate(name='concatenate')([image_input, label_embedding])
    assert concat.shape == (None, 32, 32, 4)

    # downsample to 16x16
    conv1 = Conv2D(128, kernel_size=3, strides=2, padding='same', name='conv1')(concat)
    assert conv1.shape == (None, 16, 16, 128)
    conv1 = InstanceNormalization(name='conv1_norm')(conv1)
    conv1 = LeakyReLU(alpha=0.2, name='conv1_leaky_relu')(conv1)
    
    # downsample to 8x8
    conv2 = Conv2D(128, kernel_size=3, strides=2, padding='same', name='conv2')(conv1)
    assert conv2.shape == (None, 8, 8, 128)
    conv2 = InstanceNormalization(name='conv2_norm')(conv2)
    conv2 = LeakyReLU(alpha=0.2, name='conv2_leaky_relu')(conv2)
    
    # downsample to 4x4
    conv3 = Conv2D(128, kernel_size=3, strides=2, padding='same', name='conv3')(conv2)
    assert conv3.shape == (None, 4, 4, 128)
    conv3 = InstanceNormalization(name='conv3_norm')(conv3)
    conv3 = LeakyReLU(alpha=0.2, name='conv3_leaky_relu')(conv3)

    # flatten feature maps
    flat = Flatten(name='flatten')(conv3)
    
    output = Dense(units=1, activation='sigmoid', name='output')(flat)

    model = Model(inputs=[image_input, label_input], outputs=output, name='discriminator')

    return model

# %%
create_discriminator().summary()
# Out:
# Model: "discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  label_input (InputLayer)       [(None, 1)]          0           []
#
#  label_embedding (Embedding)    (None, 1, 10)        100         ['label_input[0][0]']
#
#  label_dense (Dense)            (None, 1, 1024)      11264       ['label_embedding[0][0]']
#
#  image_input (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  label_reshape (Reshape)        (None, 32, 32, 1)    0           ['label_dense[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 4)    0           ['image_input[0][0]',
#                                                                   'label_reshape[0][0]']
#
#  conv1 (Conv2D)                 (None, 16, 16, 128)  4736        ['concatenate[0][0]']
#
#  conv1_norm (InstanceNormalizat  (None, 16, 16, 128)  256        ['conv1[0][0]']
#  ion)
#
#  conv1_leaky_relu (LeakyReLU)   (None, 16, 16, 128)  0           ['conv1_norm[0][0]']
#
#  conv2 (Conv2D)                 (None, 8, 8, 128)    147584      ['conv1_leaky_relu[0][0]']
#
#  conv2_norm (InstanceNormalizat  (None, 8, 8, 128)   256         ['conv2[0][0]']
#  ion)
#
#  conv2_leaky_relu (LeakyReLU)   (None, 8, 8, 128)    0           ['conv2_norm[0][0]']
#
#  conv3 (Conv2D)                 (None, 4, 4, 128)    147584      ['conv2_leaky_relu[0][0]']
#
#  conv3_norm (InstanceNormalizat  (None, 4, 4, 128)   256         ['conv3[0][0]']
#  ion)
#
#  conv3_leaky_relu (LeakyReLU)   (None, 4, 4, 128)    0           ['conv3_norm[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['conv3_leaky_relu[0][0]']
#
#  output (Dense)                 (None, 1)            2049        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 314,085
# Trainable params: 314,085
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# visualize discriminator
# plot_model(discriminator, show_shapes=True, to_file='images\model_architecture\Conditional_DCGAN\discriminator.png')
# discriminator_img = mpimg.imread('images\model_architecture\Conditional_DCGAN\discriminator.png')

# plt.figure(figsize=(10, 10))
# imgplot = plt.imshow(discriminator_img)
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Defining cDCGAN

# %%
class ConditionalDCGAN(Model):
    def __init__(self, generator, discriminator, latent_dim):
        super(ConditionalDCGAN, self).__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(ConditionalDCGAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        self.g_loss_metric = keras.metrics.Mean(name='g_loss')
        self.d_real_loss_metric = keras.metrics.Mean(name='d_real_loss')
        self.d_fake_loss_metric = keras.metrics.Mean(name='d_fake_loss')
        self.d_acc_metric = keras.metrics.BinaryAccuracy(name='d_acc')

    @property
    def metrics(self):
        return [self.g_loss_metric, self.d_real_loss_metric, self.d_fake_loss_metric, self.d_acc_metric]

    def train_step(self, data):
        real_images, class_labels = data
        class_labels = tf.cast(class_labels, 'int32')
        batch_size = tf.shape(real_images)[0]

        # train discriminator
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        random_class_labels = tf.random.uniform(shape=(batch_size, 1), minval=0, maxval=10, dtype='int32')

        fake_labels = tf.zeros((batch_size, 1))  # (batch_size, 1)
        real_labels = tf.ones((batch_size, 1))  # (batch_size, 1)

        # freeze generator
        self.discriminator.trainable = True
        self.generator.trainable = False
    
        with tf.GradientTape() as disc_tape:
            disc_tape.watch(self.discriminator.trainable_variables)
            generated_images = self.generator([random_latent_vectors, random_class_labels], training=True)
            real_output = self.discriminator([real_images, class_labels], training=True)
            fake_output = self.discriminator([generated_images, random_class_labels], training=True)
            d_loss_real = self.loss_fn(real_labels, real_output)
            d_loss_fake = self.loss_fn(fake_labels, fake_output)
            d_loss = d_loss_real + d_loss_fake  # log(D(x)) + log(1 - D(G(z))
        
        disc_grads = disc_tape.gradient(d_loss, self.discriminator.trainable_variables)
        self.d_optimizer.apply_gradients(zip(disc_grads, self.discriminator.trainable_variables))

        # train the generator
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        random_class_labels = tf.random.uniform(shape=(batch_size, 1), minval=0, maxval=10, dtype='int32')
        misleading_labels = tf.ones((batch_size, 1))

        # freeze discriminator
        self.discriminator.trainable = False
        self.generator.trainable = True

        with tf.GradientTape() as gen_tape:
            gen_tape.watch(self.generator.trainable_variables)
            generated_images = self.generator([random_latent_vectors, random_class_labels], training=True)
            pred_on_fake = self.discriminator([generated_images, random_class_labels], training=True)
            # negative log probability of the discriminator making the correct choice
            g_loss = self.loss_fn(misleading_labels, pred_on_fake)  # maximize log(D(G(z))) = minimize -log(1 - D(G(z)))
        
        gen_grads = gen_tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(zip(gen_grads, self.generator.trainable_variables))

        # update metrics
        self.g_loss_metric.update_state(g_loss)
        self.d_real_loss_metric.update_state(d_loss_real)
        self.d_fake_loss_metric.update_state(d_loss_fake)
        self.d_acc_metric.update_state(real_labels, real_output)

        return {
            'g_loss': self.g_loss_metric.result(),
            'd_real_loss': self.d_real_loss_metric.result(),
            'd_fake_loss': self.d_fake_loss_metric.result(),
            'd_acc': self.d_acc_metric.result()
        }

# %%
class GANMonitor(Callback):
    def __init__(self, latent_dim, label_map):
        self.latent_dim = latent_dim
        self.label_map = label_map

    def on_epoch_end(self, epoch, logs=None):
        # plot 100 generated images and save weights every 10 epochs
        latent_vectors = tf.random.normal(shape=(100, self.latent_dim))
        class_labels = tf.reshape(tf.range(10), shape=(10, 1))
        class_labels = tf.tile(class_labels, multiples=(1, 10))
        class_labels = tf.reshape(class_labels, shape=(100, 1))

        generated_images = self.model.generator([latent_vectors, class_labels], training=False)
        generated_images = (generated_images + 1) / 2

        if not os.path.exists('../assets/cdcgan_inorm'):
            os.makedirs('../assets/cdcgan_inorm')

        if not os.path.exists('../images/cdcgan_inorm_images'):
            os.makedirs('../images/cdcgan_inorm_images')

        if (epoch + 1) % 10 == 0:
            if not os.path.exists(f'../assets/cdcgan_inorm/epoch_{epoch + 1}'):
                os.makedirs(f'../assets/cdcgan_inorm/epoch_{epoch + 1}')
                self.model.generator.save_weights(f'../assets/cdcgan_inorm/epoch_{epoch + 1}/generator_weights_epoch_{epoch + 1}.h5')
                self.model.discriminator.save_weights(f'../assets/cdcgan_inorm/epoch_{epoch + 1}/discriminator_weights_epoch_{epoch + 1}.h5')
                print(f'\n\nSaving weights at epoch {epoch + 1}\n')

            fig, axes = plt.subplots(10, 10, figsize=(20, 20))
            axes = axes.flatten()

            for i, ax in enumerate(axes):
                ax.imshow(generated_images[i])
                ax.set_title(self.label_map[class_labels[i].numpy().item()], fontsize=16)
                ax.axis('off')

            plt.tight_layout()
            plt.savefig(f'../images/cdcgan_inorm_images/generated_img_{epoch + 1}.png')
            plt.close()

# %% [markdown]
# ## Training cDCGAN

# %%
EPOCHS = 200
LATENT_DIM = 128    
LEARNING_RATE = 2e-4
BETA_1 = 0.5
LABEL_SMOOTHING = 0.25

label_map = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
}

callbacks = [GANMonitor(LATENT_DIM, label_map)]

generator = create_generator(LATENT_DIM)
discriminator = create_discriminator()
cdcgan = ConditionalDCGAN(generator, discriminator, latent_dim=LATENT_DIM)
cdcgan.compile(
    g_optimizer=Adam(learning_rate=LEARNING_RATE, beta_1=BETA_1),
    d_optimizer=Adam(learning_rate=LEARNING_RATE, beta_1=BETA_1),
    loss_fn=BinaryCrossentropy(label_smoothing=LABEL_SMOOTHING)
)

# %%
# %%time
history = cdcgan.fit(dataset, epochs=EPOCHS, callbacks=callbacks, use_multiprocessing=True)
# Out:
# Epoch 1/200
# 467/467 [==============================] - 40s 65ms/step - g_loss: 2.6103 - d_real_loss: 0.5348 - d_fake_loss: 0.4830 - d_acc: 0.8530
# Epoch 2/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 2.1312 - d_real_loss: 0.5084 - d_fake_loss: 0.4243 - d_acc: 0.8873
# Epoch 3/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.8421 - d_real_loss: 0.5420 - d_fake_loss: 0.4901 - d_acc: 0.8369
# Epoch 4/200
# 467/467 [==============================] - 29s 61ms/step - g_loss: 1.8696 - d_real_loss: 0.5275 - d_fake_loss: 0.4832 - d_acc: 0.8537
# Epoch 5/200
# 467/467 [==============================] - 28s 61ms/step - g_loss: 1.8315 - d_real_loss: 0.5342 - d_fake_loss: 0.4813 - d_acc: 0.8455
# Epoch 6/200
# 467/467 [==============================] - 28s 61ms/step - g_loss: 1.8266 - d_real_loss: 0.5266 - d_fake_loss: 0.4723 - d_acc: 0.8541
# Epoch 7/200
# 467/467 [==============================] - 28s 61ms/step - g_loss: 1.7634 - d_real_loss: 0.5260 - d_fake_loss: 0.4655 - d_acc: 0.8543
# Epoch 8/200
# 467/467 [==============================] - 29s 61ms/step - g_loss: 1.8119 - d_real_loss: 0.5133 - d_fake_loss: 0.4582 - d_acc: 0.8730
# Epoch 9/200
# 467/467 [==============================] - 28s 61ms/step - g_loss: 1.7865 - d_real_loss: 0.5068 - d_fake_loss: 0.4523 - d_acc: 0.8805
# Epoch 10/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.7817 - d_real_loss: 0.5054 - d_fake_loss: 0.4572 - d_acc: 0.8805
#
# Saving weights at epoch 10
#
# 467/467 [==============================] - 34s 74ms/step - g_loss: 1.7817 - d_real_loss: 0.5054 - d_fake_loss: 0.4572 - d_acc: 0.8805
# Epoch 11/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.8533 - d_real_loss: 0.4958 - d_fake_loss: 0.4474 - d_acc: 0.8926
# Epoch 12/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.8106 - d_real_loss: 0.4979 - d_fake_loss: 0.4504 - d_acc: 0.8885
# Epoch 13/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.7508 - d_real_loss: 0.5034 - d_fake_loss: 0.4498 - d_acc: 0.8815
# Epoch 14/200
# 467/467 [==============================] - 30s 65ms/step - g_loss: 1.7670 - d_real_loss: 0.5042 - d_fake_loss: 0.4509 - d_acc: 0.8815
# Epoch 15/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.7033 - d_real_loss: 0.5154 - d_fake_loss: 0.4589 - d_acc: 0.8656
# Epoch 16/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.7011 - d_real_loss: 0.5127 - d_fake_loss: 0.4616 - d_acc: 0.8684
# Epoch 17/200
# 467/467 [==============================] - 29s 61ms/step - g_loss: 1.5751 - d_real_loss: 0.5222 - d_fake_loss: 0.4774 - d_acc: 0.8533
# Epoch 18/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.5891 - d_real_loss: 0.5264 - d_fake_loss: 0.4846 - d_acc: 0.8536
# Epoch 19/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.5271 - d_real_loss: 0.5220 - d_fake_loss: 0.4810 - d_acc: 0.8553
# Epoch 20/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.5507 - d_real_loss: 0.5200 - d_fake_loss: 0.4718 - d_acc: 0.8618
#
# Saving weights at epoch 20
#
# 467/467 [==============================] - 35s 74ms/step - g_loss: 1.5507 - d_real_loss: 0.5200 - d_fake_loss: 0.4718 - d_acc: 0.8618
# Epoch 21/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.4911 - d_real_loss: 0.5366 - d_fake_loss: 0.4916 - d_acc: 0.8377
# Epoch 22/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.4870 - d_real_loss: 0.5286 - d_fake_loss: 0.4789 - d_acc: 0.8476
# Epoch 23/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.5843 - d_real_loss: 0.5095 - d_fake_loss: 0.4765 - d_acc: 0.8745
# Epoch 24/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3984 - d_real_loss: 0.5333 - d_fake_loss: 0.4960 - d_acc: 0.8373
# Epoch 25/200
# 467/467 [==============================] - 30s 63ms/step - g_loss: 1.3540 - d_real_loss: 0.5417 - d_fake_loss: 0.5080 - d_acc: 0.8253
# Epoch 26/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3631 - d_real_loss: 0.5451 - d_fake_loss: 0.5104 - d_acc: 0.8239
# Epoch 27/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3929 - d_real_loss: 0.5396 - d_fake_loss: 0.5046 - d_acc: 0.8320
# Epoch 28/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3746 - d_real_loss: 0.5385 - d_fake_loss: 0.5031 - d_acc: 0.8311
# Epoch 29/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3787 - d_real_loss: 0.5394 - d_fake_loss: 0.5087 - d_acc: 0.8335
# Epoch 30/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.3625 - d_real_loss: 0.5331 - d_fake_loss: 0.4984 - d_acc: 0.8405
#
# Saving weights at epoch 30
#
# 467/467 [==============================] - 35s 75ms/step - g_loss: 1.3625 - d_real_loss: 0.5331 - d_fake_loss: 0.4984 - d_acc: 0.8405
# Epoch 31/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3675 - d_real_loss: 0.5340 - d_fake_loss: 0.4989 - d_acc: 0.8386
# Epoch 32/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3431 - d_real_loss: 0.5409 - d_fake_loss: 0.5078 - d_acc: 0.8324
# Epoch 33/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3460 - d_real_loss: 0.5387 - d_fake_loss: 0.5041 - d_acc: 0.8321
# Epoch 34/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3501 - d_real_loss: 0.5373 - d_fake_loss: 0.5034 - d_acc: 0.8336
# Epoch 35/200
# 467/467 [==============================] - 30s 63ms/step - g_loss: 1.3308 - d_real_loss: 0.5407 - d_fake_loss: 0.5100 - d_acc: 0.8315
# Epoch 36/200
# 467/467 [==============================] - 30s 65ms/step - g_loss: 1.3347 - d_real_loss: 0.5355 - d_fake_loss: 0.5020 - d_acc: 0.8351
# Epoch 37/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3354 - d_real_loss: 0.5416 - d_fake_loss: 0.5112 - d_acc: 0.8286
# Epoch 38/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3241 - d_real_loss: 0.5444 - d_fake_loss: 0.5126 - d_acc: 0.8257
# Epoch 39/200
# 467/467 [==============================] - 31s 66ms/step - g_loss: 1.3367 - d_real_loss: 0.5391 - d_fake_loss: 0.5061 - d_acc: 0.8301
# Epoch 40/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.3060 - d_real_loss: 0.5474 - d_fake_loss: 0.5162 - d_acc: 0.8222
#
# Saving weights at epoch 40
#
# 467/467 [==============================] - 36s 77ms/step - g_loss: 1.3060 - d_real_loss: 0.5474 - d_fake_loss: 0.5162 - d_acc: 0.8222
# Epoch 41/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3200 - d_real_loss: 0.5389 - d_fake_loss: 0.5067 - d_acc: 0.8286
# Epoch 42/200
# 467/467 [==============================] - 30s 63ms/step - g_loss: 1.2987 - d_real_loss: 0.5513 - d_fake_loss: 0.5232 - d_acc: 0.8158
# Epoch 43/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2954 - d_real_loss: 0.5512 - d_fake_loss: 0.5226 - d_acc: 0.8168
# Epoch 44/200
# 467/467 [==============================] - 30s 65ms/step - g_loss: 1.3040 - d_real_loss: 0.5418 - d_fake_loss: 0.5100 - d_acc: 0.8270
# Epoch 45/200
# 467/467 [==============================] - 30s 65ms/step - g_loss: 1.2877 - d_real_loss: 0.5506 - d_fake_loss: 0.5223 - d_acc: 0.8151
# Epoch 46/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2928 - d_real_loss: 0.5452 - d_fake_loss: 0.5137 - d_acc: 0.8219
# Epoch 47/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2968 - d_real_loss: 0.5477 - d_fake_loss: 0.5158 - d_acc: 0.8206
# Epoch 48/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2868 - d_real_loss: 0.5492 - d_fake_loss: 0.5197 - d_acc: 0.8202
# Epoch 49/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.2928 - d_real_loss: 0.5479 - d_fake_loss: 0.5177 - d_acc: 0.8224
# Epoch 50/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.2833 - d_real_loss: 0.5554 - d_fake_loss: 0.5280 - d_acc: 0.8118
#
# Saving weights at epoch 50
#
# 467/467 [==============================] - 35s 75ms/step - g_loss: 1.2833 - d_real_loss: 0.5554 - d_fake_loss: 0.5280 - d_acc: 0.8118
# Epoch 51/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.2772 - d_real_loss: 0.5404 - d_fake_loss: 0.5091 - d_acc: 0.8265
# Epoch 52/200
# 467/467 [==============================] - 29s 61ms/step - g_loss: 1.2852 - d_real_loss: 0.5427 - d_fake_loss: 0.5144 - d_acc: 0.8253
# Epoch 53/200
# 467/467 [==============================] - 28s 61ms/step - g_loss: 1.3004 - d_real_loss: 0.5440 - d_fake_loss: 0.5164 - d_acc: 0.8269
# Epoch 54/200
# 467/467 [==============================] - 29s 61ms/step - g_loss: 1.2940 - d_real_loss: 0.5397 - d_fake_loss: 0.5102 - d_acc: 0.8290
# Epoch 55/200
# 467/467 [==============================] - 30s 63ms/step - g_loss: 1.2839 - d_real_loss: 0.5544 - d_fake_loss: 0.5279 - d_acc: 0.8157
# Epoch 56/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2890 - d_real_loss: 0.5455 - d_fake_loss: 0.5185 - d_acc: 0.8229
# Epoch 57/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2884 - d_real_loss: 0.5399 - d_fake_loss: 0.5119 - d_acc: 0.8274
# Epoch 58/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.2784 - d_real_loss: 0.5532 - d_fake_loss: 0.5284 - d_acc: 0.8141
# Epoch 59/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2728 - d_real_loss: 0.5484 - d_fake_loss: 0.5241 - d_acc: 0.8178
# Epoch 60/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.2784 - d_real_loss: 0.5486 - d_fake_loss: 0.5260 - d_acc: 0.8206
#
# Saving weights at epoch 60
#
# 467/467 [==============================] - 35s 74ms/step - g_loss: 1.2784 - d_real_loss: 0.5486 - d_fake_loss: 0.5260 - d_acc: 0.8206
# Epoch 61/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2834 - d_real_loss: 0.5455 - d_fake_loss: 0.5210 - d_acc: 0.8220
# Epoch 62/200
# 467/467 [==============================] - 30s 65ms/step - g_loss: 1.2748 - d_real_loss: 0.5411 - d_fake_loss: 0.5159 - d_acc: 0.8274
# Epoch 63/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2812 - d_real_loss: 0.5422 - d_fake_loss: 0.5178 - d_acc: 0.8243
# Epoch 64/200
# 467/467 [==============================] - 28s 61ms/step - g_loss: 1.2758 - d_real_loss: 0.5447 - d_fake_loss: 0.5213 - d_acc: 0.8235
# Epoch 65/200
# 467/467 [==============================] - 28s 61ms/step - g_loss: 1.2901 - d_real_loss: 0.5464 - d_fake_loss: 0.5235 - d_acc: 0.8228
# Epoch 66/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2829 - d_real_loss: 0.5470 - d_fake_loss: 0.5249 - d_acc: 0.8242
# Epoch 67/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2906 - d_real_loss: 0.5422 - d_fake_loss: 0.5186 - d_acc: 0.8260
# Epoch 68/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2845 - d_real_loss: 0.5449 - d_fake_loss: 0.5245 - d_acc: 0.8246
# Epoch 69/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2853 - d_real_loss: 0.5482 - d_fake_loss: 0.5289 - d_acc: 0.8209
# Epoch 70/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.2762 - d_real_loss: 0.5377 - d_fake_loss: 0.5164 - d_acc: 0.8319
#
# Saving weights at epoch 70
#
# 467/467 [==============================] - 36s 78ms/step - g_loss: 1.2762 - d_real_loss: 0.5377 - d_fake_loss: 0.5164 - d_acc: 0.8319
# Epoch 71/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2903 - d_real_loss: 0.5439 - d_fake_loss: 0.5240 - d_acc: 0.8259
# Epoch 72/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2915 - d_real_loss: 0.5399 - d_fake_loss: 0.5202 - d_acc: 0.8275
# Epoch 73/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2764 - d_real_loss: 0.5450 - d_fake_loss: 0.5267 - d_acc: 0.8269
# Epoch 74/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2916 - d_real_loss: 0.5381 - d_fake_loss: 0.5187 - d_acc: 0.8316
# Epoch 75/200
# 467/467 [==============================] - 30s 63ms/step - g_loss: 1.2806 - d_real_loss: 0.5454 - d_fake_loss: 0.5275 - d_acc: 0.8254
# Epoch 76/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.2958 - d_real_loss: 0.5429 - d_fake_loss: 0.5266 - d_acc: 0.8310
# Epoch 77/200
# 467/467 [==============================] - 29s 61ms/step - g_loss: 1.2843 - d_real_loss: 0.5368 - d_fake_loss: 0.5187 - d_acc: 0.8347
# Epoch 78/200
# 467/467 [==============================] - 29s 61ms/step - g_loss: 1.2843 - d_real_loss: 0.5491 - d_fake_loss: 0.5324 - d_acc: 0.8229
# Epoch 79/200
# 467/467 [==============================] - 29s 61ms/step - g_loss: 1.2856 - d_real_loss: 0.5331 - d_fake_loss: 0.5165 - d_acc: 0.8395
# Epoch 80/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.2873 - d_real_loss: 0.5382 - d_fake_loss: 0.5222 - d_acc: 0.8329
#
# Saving weights at epoch 80
#
# 467/467 [==============================] - 36s 78ms/step - g_loss: 1.2873 - d_real_loss: 0.5382 - d_fake_loss: 0.5222 - d_acc: 0.8329
# Epoch 81/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2880 - d_real_loss: 0.5435 - d_fake_loss: 0.5297 - d_acc: 0.8292
# Epoch 82/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2918 - d_real_loss: 0.5344 - d_fake_loss: 0.5195 - d_acc: 0.8374
# Epoch 83/200
# 467/467 [==============================] - 30s 63ms/step - g_loss: 1.2866 - d_real_loss: 0.5398 - d_fake_loss: 0.5263 - d_acc: 0.8328
# Epoch 84/200
# 467/467 [==============================] - 30s 63ms/step - g_loss: 1.2938 - d_real_loss: 0.5428 - d_fake_loss: 0.5295 - d_acc: 0.8289
# Epoch 85/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2854 - d_real_loss: 0.5325 - d_fake_loss: 0.5181 - d_acc: 0.8398
# Epoch 86/200
# 467/467 [==============================] - 30s 65ms/step - g_loss: 1.2883 - d_real_loss: 0.5395 - d_fake_loss: 0.5262 - d_acc: 0.8326
# Epoch 87/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2876 - d_real_loss: 0.5457 - d_fake_loss: 0.5360 - d_acc: 0.8280
# Epoch 88/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.2834 - d_real_loss: 0.5293 - d_fake_loss: 0.5168 - d_acc: 0.8439
# Epoch 89/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2933 - d_real_loss: 0.5391 - d_fake_loss: 0.5279 - d_acc: 0.8368
# Epoch 90/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.2863 - d_real_loss: 0.5429 - d_fake_loss: 0.5336 - d_acc: 0.8318
#
# Saving weights at epoch 90
#
# 467/467 [==============================] - 36s 78ms/step - g_loss: 1.2863 - d_real_loss: 0.5429 - d_fake_loss: 0.5336 - d_acc: 0.8318
# Epoch 91/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.2947 - d_real_loss: 0.5283 - d_fake_loss: 0.5170 - d_acc: 0.8456
# Epoch 92/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3065 - d_real_loss: 0.5325 - d_fake_loss: 0.5223 - d_acc: 0.8412
# Epoch 93/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.2967 - d_real_loss: 0.5354 - d_fake_loss: 0.5261 - d_acc: 0.8393
# Epoch 94/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3019 - d_real_loss: 0.5316 - d_fake_loss: 0.5228 - d_acc: 0.8413
# Epoch 95/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3012 - d_real_loss: 0.5336 - d_fake_loss: 0.5248 - d_acc: 0.8396
# Epoch 96/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3103 - d_real_loss: 0.5286 - d_fake_loss: 0.5201 - d_acc: 0.8466
# Epoch 97/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3087 - d_real_loss: 0.5251 - d_fake_loss: 0.5169 - d_acc: 0.8494
# Epoch 98/200
# 467/467 [==============================] - 30s 65ms/step - g_loss: 1.3081 - d_real_loss: 0.5371 - d_fake_loss: 0.5301 - d_acc: 0.8404
# Epoch 99/200
# 467/467 [==============================] - 30s 65ms/step - g_loss: 1.3188 - d_real_loss: 0.5229 - d_fake_loss: 0.5160 - d_acc: 0.8531
# Epoch 100/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.3072 - d_real_loss: 0.5298 - d_fake_loss: 0.5244 - d_acc: 0.8459
#
# Saving weights at epoch 100
#
# 467/467 [==============================] - 35s 75ms/step - g_loss: 1.3072 - d_real_loss: 0.5298 - d_fake_loss: 0.5244 - d_acc: 0.8459
# Epoch 101/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3142 - d_real_loss: 0.5296 - d_fake_loss: 0.5243 - d_acc: 0.8490
# Epoch 102/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3142 - d_real_loss: 0.5271 - d_fake_loss: 0.5220 - d_acc: 0.8493
# Epoch 103/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3245 - d_real_loss: 0.5203 - d_fake_loss: 0.5152 - d_acc: 0.8579
# Epoch 104/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.3240 - d_real_loss: 0.5236 - d_fake_loss: 0.5191 - d_acc: 0.8533
# Epoch 105/200
# 467/467 [==============================] - 29s 62ms/step - g_loss: 1.3279 - d_real_loss: 0.5254 - d_fake_loss: 0.5217 - d_acc: 0.8525
# Epoch 106/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3319 - d_real_loss: 0.5196 - d_fake_loss: 0.5159 - d_acc: 0.8595
# Epoch 107/200
# 467/467 [==============================] - 29s 63ms/step - g_loss: 1.3302 - d_real_loss: 0.5304 - d_fake_loss: 0.5277 - d_acc: 0.8506
# Epoch 108/200
# 467/467 [==============================] - 30s 64ms/step - g_loss: 1.3338 - d_real_loss: 0.5181 - d_fake_loss: 0.5142 - d_acc: 0.8605
# Epoch 109/200
# 467/467 [==============================] - 56s 121ms/step - g_loss: 1.3248 - d_real_loss: 0.5260 - d_fake_loss: 0.5253 - d_acc: 0.8559
# Epoch 110/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.3366 - d_real_loss: 0.5291 - d_fake_loss: 0.5289 - d_acc: 0.8510
#
# Saving weights at epoch 110
#
# 467/467 [==============================] - 64s 137ms/step - g_loss: 1.3366 - d_real_loss: 0.5291 - d_fake_loss: 0.5289 - d_acc: 0.8510
# Epoch 111/200
# 467/467 [==============================] - 57s 122ms/step - g_loss: 1.3352 - d_real_loss: 0.5150 - d_fake_loss: 0.5132 - d_acc: 0.8666
# Epoch 112/200
# 467/467 [==============================] - 57s 123ms/step - g_loss: 1.3538 - d_real_loss: 0.5178 - d_fake_loss: 0.5161 - d_acc: 0.8629
# Epoch 113/200
# 467/467 [==============================] - 58s 124ms/step - g_loss: 1.3449 - d_real_loss: 0.5212 - d_fake_loss: 0.5203 - d_acc: 0.8629
# Epoch 114/200
# 467/467 [==============================] - 58s 123ms/step - g_loss: 1.3445 - d_real_loss: 0.5173 - d_fake_loss: 0.5164 - d_acc: 0.8654
# Epoch 115/200
# 467/467 [==============================] - 51s 110ms/step - g_loss: 1.3557 - d_real_loss: 0.5143 - d_fake_loss: 0.5137 - d_acc: 0.8677
# Epoch 116/200
# 467/467 [==============================] - 58s 125ms/step - g_loss: 1.3552 - d_real_loss: 0.5146 - d_fake_loss: 0.5154 - d_acc: 0.8673
# Epoch 117/200
# 467/467 [==============================] - 59s 125ms/step - g_loss: 1.3382 - d_real_loss: 0.5285 - d_fake_loss: 0.5315 - d_acc: 0.8560
# Epoch 118/200
# 467/467 [==============================] - 58s 124ms/step - g_loss: 1.3550 - d_real_loss: 0.5108 - d_fake_loss: 0.5113 - d_acc: 0.8727
# Epoch 119/200
# 467/467 [==============================] - 57s 122ms/step - g_loss: 1.3614 - d_real_loss: 0.5143 - d_fake_loss: 0.5163 - d_acc: 0.8703
# Epoch 120/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.3692 - d_real_loss: 0.5114 - d_fake_loss: 0.5131 - d_acc: 0.8707
#
# Saving weights at epoch 120
#
# 467/467 [==============================] - 63s 136ms/step - g_loss: 1.3692 - d_real_loss: 0.5114 - d_fake_loss: 0.5131 - d_acc: 0.8707
# Epoch 121/200
# 467/467 [==============================] - 51s 109ms/step - g_loss: 1.3711 - d_real_loss: 0.5109 - d_fake_loss: 0.5129 - d_acc: 0.8721
# Epoch 122/200
# 467/467 [==============================] - 55s 118ms/step - g_loss: 1.3476 - d_real_loss: 0.5256 - d_fake_loss: 0.5291 - d_acc: 0.8620
# Epoch 123/200
# 467/467 [==============================] - 57s 121ms/step - g_loss: 1.3745 - d_real_loss: 0.5167 - d_fake_loss: 0.5195 - d_acc: 0.8688
# Epoch 124/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.3682 - d_real_loss: 0.5069 - d_fake_loss: 0.5102 - d_acc: 0.8801
# Epoch 125/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.3742 - d_real_loss: 0.5092 - d_fake_loss: 0.5132 - d_acc: 0.8764
# Epoch 126/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.3735 - d_real_loss: 0.5219 - d_fake_loss: 0.5266 - d_acc: 0.8663
# Epoch 127/200
# 467/467 [==============================] - 57s 122ms/step - g_loss: 1.3796 - d_real_loss: 0.5042 - d_fake_loss: 0.5085 - d_acc: 0.8832
# Epoch 128/200
# 467/467 [==============================] - 50s 108ms/step - g_loss: 1.3731 - d_real_loss: 0.5168 - d_fake_loss: 0.5215 - d_acc: 0.8689
# Epoch 129/200
# 467/467 [==============================] - 57s 123ms/step - g_loss: 1.3817 - d_real_loss: 0.5057 - d_fake_loss: 0.5101 - d_acc: 0.8805
# Epoch 130/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.3913 - d_real_loss: 0.5040 - d_fake_loss: 0.5088 - d_acc: 0.8822
#
# Saving weights at epoch 130
#
# 467/467 [==============================] - 65s 138ms/step - g_loss: 1.3913 - d_real_loss: 0.5040 - d_fake_loss: 0.5088 - d_acc: 0.8822
# Epoch 131/200
# 467/467 [==============================] - 55s 118ms/step - g_loss: 1.3873 - d_real_loss: 0.5176 - d_fake_loss: 0.5254 - d_acc: 0.8698
# Epoch 132/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.3799 - d_real_loss: 0.5013 - d_fake_loss: 0.5068 - d_acc: 0.8883
# Epoch 133/200
# 467/467 [==============================] - 55s 117ms/step - g_loss: 1.3854 - d_real_loss: 0.5089 - d_fake_loss: 0.5159 - d_acc: 0.8801
# Epoch 134/200
# 467/467 [==============================] - 49s 104ms/step - g_loss: 1.3930 - d_real_loss: 0.5014 - d_fake_loss: 0.5077 - d_acc: 0.8875
# Epoch 135/200
# 467/467 [==============================] - 54s 115ms/step - g_loss: 1.3988 - d_real_loss: 0.5170 - d_fake_loss: 0.5252 - d_acc: 0.8730
# Epoch 136/200
# 467/467 [==============================] - 56s 121ms/step - g_loss: 1.3912 - d_real_loss: 0.5020 - d_fake_loss: 0.5071 - d_acc: 0.8860
# Epoch 137/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.4045 - d_real_loss: 0.4987 - d_fake_loss: 0.5070 - d_acc: 0.8911
# Epoch 138/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.4083 - d_real_loss: 0.5017 - d_fake_loss: 0.5095 - d_acc: 0.8862
# Epoch 139/200
# 467/467 [==============================] - 54s 116ms/step - g_loss: 1.3380 - d_real_loss: 0.5347 - d_fake_loss: 0.5423 - d_acc: 0.8527
# Epoch 140/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.4056 - d_real_loss: 0.4999 - d_fake_loss: 0.5083 - d_acc: 0.8902
#
# Saving weights at epoch 140
#
# 467/467 [==============================] - 67s 144ms/step - g_loss: 1.4056 - d_real_loss: 0.4999 - d_fake_loss: 0.5083 - d_acc: 0.8902
# Epoch 141/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.4008 - d_real_loss: 0.5052 - d_fake_loss: 0.5142 - d_acc: 0.8853
# Epoch 142/200
# 467/467 [==============================] - 55s 118ms/step - g_loss: 1.4173 - d_real_loss: 0.4961 - d_fake_loss: 0.5055 - d_acc: 0.8960
# Epoch 143/200
# 467/467 [==============================] - 60s 129ms/step - g_loss: 1.4019 - d_real_loss: 0.5107 - d_fake_loss: 0.5209 - d_acc: 0.8793
# Epoch 144/200
# 467/467 [==============================] - 58s 124ms/step - g_loss: 1.4219 - d_real_loss: 0.4971 - d_fake_loss: 0.5067 - d_acc: 0.8938
# Epoch 145/200
# 467/467 [==============================] - 58s 124ms/step - g_loss: 1.4113 - d_real_loss: 0.5066 - d_fake_loss: 0.5162 - d_acc: 0.8857
# Epoch 146/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.4173 - d_real_loss: 0.4941 - d_fake_loss: 0.5044 - d_acc: 0.8992
# Epoch 147/200
# 467/467 [==============================] - 49s 106ms/step - g_loss: 1.4124 - d_real_loss: 0.5058 - d_fake_loss: 0.5159 - d_acc: 0.8876
# Epoch 148/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.4293 - d_real_loss: 0.4944 - d_fake_loss: 0.5063 - d_acc: 0.8986
# Epoch 149/200
# 467/467 [==============================] - 57s 121ms/step - g_loss: 1.4356 - d_real_loss: 0.4969 - d_fake_loss: 0.5084 - d_acc: 0.8952
# Epoch 150/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.4234 - d_real_loss: 0.4958 - d_fake_loss: 0.5064 - d_acc: 0.8972
#
# Saving weights at epoch 150
#
# 467/467 [==============================] - 63s 136ms/step - g_loss: 1.4234 - d_real_loss: 0.4958 - d_fake_loss: 0.5064 - d_acc: 0.8972
# Epoch 151/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.4070 - d_real_loss: 0.5145 - d_fake_loss: 0.5271 - d_acc: 0.8785
# Epoch 152/200
# 467/467 [==============================] - 57s 122ms/step - g_loss: 1.4308 - d_real_loss: 0.4912 - d_fake_loss: 0.5029 - d_acc: 0.9044
# Epoch 153/200
# 467/467 [==============================] - 51s 110ms/step - g_loss: 1.4381 - d_real_loss: 0.4931 - d_fake_loss: 0.5072 - d_acc: 0.9006
# Epoch 154/200
# 467/467 [==============================] - 58s 125ms/step - g_loss: 1.4256 - d_real_loss: 0.5059 - d_fake_loss: 0.5203 - d_acc: 0.8903
# Epoch 155/200
# 467/467 [==============================] - 58s 125ms/step - g_loss: 1.4402 - d_real_loss: 0.4906 - d_fake_loss: 0.5034 - d_acc: 0.9037
# Epoch 156/200
# 467/467 [==============================] - 57s 123ms/step - g_loss: 1.4456 - d_real_loss: 0.4930 - d_fake_loss: 0.5067 - d_acc: 0.9010
# Epoch 157/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.4523 - d_real_loss: 0.4915 - d_fake_loss: 0.5049 - d_acc: 0.9013
# Epoch 158/200
# 467/467 [==============================] - 57s 121ms/step - g_loss: 1.4425 - d_real_loss: 0.4926 - d_fake_loss: 0.5066 - d_acc: 0.9023
# Epoch 159/200
# 467/467 [==============================] - 57s 123ms/step - g_loss: 1.4506 - d_real_loss: 0.4921 - d_fake_loss: 0.5061 - d_acc: 0.9009
# Epoch 160/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.4499 - d_real_loss: 0.4963 - d_fake_loss: 0.5103 - d_acc: 0.8990
#
# Saving weights at epoch 160
#
# 467/467 [==============================] - 57s 122ms/step - g_loss: 1.4499 - d_real_loss: 0.4963 - d_fake_loss: 0.5103 - d_acc: 0.8990
# Epoch 161/200
# 467/467 [==============================] - 57s 123ms/step - g_loss: 1.4520 - d_real_loss: 0.4916 - d_fake_loss: 0.5070 - d_acc: 0.9040
# Epoch 162/200
# 467/467 [==============================] - 58s 124ms/step - g_loss: 1.4536 - d_real_loss: 0.4883 - d_fake_loss: 0.5034 - d_acc: 0.9066
# Epoch 163/200
# 467/467 [==============================] - 57s 121ms/step - g_loss: 1.4558 - d_real_loss: 0.5002 - d_fake_loss: 0.5153 - d_acc: 0.8970
# Epoch 164/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.4499 - d_real_loss: 0.4875 - d_fake_loss: 0.5022 - d_acc: 0.9103
# Epoch 165/200
# 467/467 [==============================] - 58s 125ms/step - g_loss: 1.4699 - d_real_loss: 0.4879 - d_fake_loss: 0.5032 - d_acc: 0.9071
# Epoch 166/200
# 467/467 [==============================] - 50s 108ms/step - g_loss: 1.4625 - d_real_loss: 0.4889 - d_fake_loss: 0.5045 - d_acc: 0.9071
# Epoch 167/200
# 467/467 [==============================] - 54s 116ms/step - g_loss: 1.4387 - d_real_loss: 0.5055 - d_fake_loss: 0.5214 - d_acc: 0.8954
# Epoch 168/200
# 467/467 [==============================] - 52s 112ms/step - g_loss: 1.4701 - d_real_loss: 0.4840 - d_fake_loss: 0.5002 - d_acc: 0.9137
# Epoch 169/200
# 467/467 [==============================] - 52s 112ms/step - g_loss: 1.4613 - d_real_loss: 0.4926 - d_fake_loss: 0.5094 - d_acc: 0.9043
# Epoch 170/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.4773 - d_real_loss: 0.4853 - d_fake_loss: 0.5026 - d_acc: 0.9111
#
# Saving weights at epoch 170
#
# 467/467 [==============================] - 58s 124ms/step - g_loss: 1.4773 - d_real_loss: 0.4853 - d_fake_loss: 0.5026 - d_acc: 0.9111
# Epoch 171/200
# 467/467 [==============================] - 52s 112ms/step - g_loss: 1.4650 - d_real_loss: 0.4930 - d_fake_loss: 0.5097 - d_acc: 0.9056
# Epoch 172/200
# 467/467 [==============================] - 48s 103ms/step - g_loss: 1.4777 - d_real_loss: 0.4839 - d_fake_loss: 0.5019 - d_acc: 0.9141
# Epoch 173/200
# 467/467 [==============================] - 50s 106ms/step - g_loss: 1.4753 - d_real_loss: 0.4859 - d_fake_loss: 0.5046 - d_acc: 0.9118
# Epoch 174/200
# 467/467 [==============================] - 53s 114ms/step - g_loss: 1.4847 - d_real_loss: 0.4851 - d_fake_loss: 0.5025 - d_acc: 0.9124
# Epoch 175/200
# 467/467 [==============================] - 54s 116ms/step - g_loss: 1.4814 - d_real_loss: 0.4848 - d_fake_loss: 0.5039 - d_acc: 0.9133
# Epoch 176/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.4617 - d_real_loss: 0.4941 - d_fake_loss: 0.5134 - d_acc: 0.9056
# Epoch 177/200
# 467/467 [==============================] - 55s 118ms/step - g_loss: 1.4825 - d_real_loss: 0.4824 - d_fake_loss: 0.5021 - d_acc: 0.9175
# Epoch 178/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.4766 - d_real_loss: 0.4915 - d_fake_loss: 0.5108 - d_acc: 0.9080
# Epoch 179/200
# 467/467 [==============================] - 50s 106ms/step - g_loss: 1.4845 - d_real_loss: 0.4817 - d_fake_loss: 0.5010 - d_acc: 0.9178
# Epoch 180/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.4935 - d_real_loss: 0.4812 - d_fake_loss: 0.5017 - d_acc: 0.9188
#
# Saving weights at epoch 180
#
# 467/467 [==============================] - 64s 137ms/step - g_loss: 1.4935 - d_real_loss: 0.4812 - d_fake_loss: 0.5017 - d_acc: 0.9188
# Epoch 181/200
# 467/467 [==============================] - 57s 122ms/step - g_loss: 1.4896 - d_real_loss: 0.4825 - d_fake_loss: 0.5023 - d_acc: 0.9160
# Epoch 182/200
# 467/467 [==============================] - 56s 121ms/step - g_loss: 1.4920 - d_real_loss: 0.4822 - d_fake_loss: 0.5028 - d_acc: 0.9182
# Epoch 183/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.4920 - d_real_loss: 0.4816 - d_fake_loss: 0.5020 - d_acc: 0.9160
# Epoch 184/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.4852 - d_real_loss: 0.4953 - d_fake_loss: 0.5156 - d_acc: 0.9076
# Epoch 185/200
# 467/467 [==============================] - 50s 106ms/step - g_loss: 1.4861 - d_real_loss: 0.4786 - d_fake_loss: 0.4996 - d_acc: 0.9235
# Epoch 186/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.4954 - d_real_loss: 0.4882 - d_fake_loss: 0.5110 - d_acc: 0.9133
# Epoch 187/200
# 467/467 [==============================] - 56s 120ms/step - g_loss: 1.4938 - d_real_loss: 0.4777 - d_fake_loss: 0.4989 - d_acc: 0.9238
# Epoch 188/200
# 467/467 [==============================] - 54s 116ms/step - g_loss: 1.5060 - d_real_loss: 0.4774 - d_fake_loss: 0.4994 - d_acc: 0.9250
# Epoch 189/200
# 467/467 [==============================] - 55s 118ms/step - g_loss: 1.5014 - d_real_loss: 0.4800 - d_fake_loss: 0.5028 - d_acc: 0.9205
# Epoch 190/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.4908 - d_real_loss: 0.4885 - d_fake_loss: 0.5093 - d_acc: 0.9136
#
# Saving weights at epoch 190
#
# 467/467 [==============================] - 64s 138ms/step - g_loss: 1.4908 - d_real_loss: 0.4885 - d_fake_loss: 0.5093 - d_acc: 0.9136
# Epoch 191/200
# 467/467 [==============================] - 53s 114ms/step - g_loss: 1.5076 - d_real_loss: 0.4772 - d_fake_loss: 0.4998 - d_acc: 0.9240
# Epoch 192/200
# 467/467 [==============================] - 50s 107ms/step - g_loss: 1.5084 - d_real_loss: 0.4787 - d_fake_loss: 0.5025 - d_acc: 0.9219
# Epoch 193/200
# 467/467 [==============================] - 55s 117ms/step - g_loss: 1.5067 - d_real_loss: 0.4779 - d_fake_loss: 0.5018 - d_acc: 0.9233
# Epoch 194/200
# 467/467 [==============================] - 55s 119ms/step - g_loss: 1.5046 - d_real_loss: 0.4794 - d_fake_loss: 0.5036 - d_acc: 0.9207
# Epoch 195/200
# 467/467 [==============================] - 55s 119ms/step - g_loss: 1.5065 - d_real_loss: 0.4767 - d_fake_loss: 0.5002 - d_acc: 0.9252
# Epoch 196/200
# 467/467 [==============================] - 55s 119ms/step - g_loss: 1.5090 - d_real_loss: 0.4836 - d_fake_loss: 0.5067 - d_acc: 0.9189
# Epoch 197/200
# 467/467 [==============================] - 56s 119ms/step - g_loss: 1.4990 - d_real_loss: 0.4938 - d_fake_loss: 0.5170 - d_acc: 0.9136
# Epoch 198/200
# 467/467 [==============================] - 50s 107ms/step - g_loss: 1.4984 - d_real_loss: 0.4731 - d_fake_loss: 0.4971 - d_acc: 0.9337
# Epoch 199/200
# 467/467 [==============================] - 55s 119ms/step - g_loss: 1.5187 - d_real_loss: 0.4751 - d_fake_loss: 0.5000 - d_acc: 0.9281
# Epoch 200/200
# 467/467 [==============================] - ETA: 0s - g_loss: 1.5224 - d_real_loss: 0.4750 - d_fake_loss: 0.4999 - d_acc: 0.9287
#
# Saving weights at epoch 200
#
# 467/467 [==============================] - 61s 132ms/step - g_loss: 1.5224 - d_real_loss: 0.4750 - d_fake_loss: 0.4999 - d_acc: 0.9287
# CPU times: total: 3h 6min 11s
# Wall time: 2h 20min 22s

# %% [markdown]
# ## Model Evaluation

# %%
plt.figure(figsize=(12,6))

plt.plot(history.history['g_loss'], label='gen_loss')
plt.plot(history.history['d_real_loss'], label='disc_real_loss')
plt.plot(history.history['d_fake_loss'], label='disc_fake_loss')

plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(history.history['d_acc'], label='disc_acc')

plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)

plt.show()

# %%
latent_vectors = tf.random.normal(shape=(100, LATENT_DIM))
class_labels = tf.reshape(tf.range(10), shape=(10, 1))
class_labels = tf.tile(class_labels, multiples=(1, 10))
class_labels = tf.reshape(class_labels, shape=(100, 1))

generated_images = cdcgan.generator([latent_vectors, class_labels], training=False)
generated_images = (generated_images + 1) / 2

# %%
fig, axes = plt.subplots(10, 10, figsize=(20, 20))
axes = axes.flatten()

for i, ax in enumerate(axes):
    ax.imshow(generated_images[i], cmap='gray')
    ax.set_title(label_map[class_labels[i].numpy().item()], fontsize=18)
    ax.axis('off')

plt.tight_layout()
plt.show()

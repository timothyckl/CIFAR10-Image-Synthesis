# %% [markdown]
# # Experiment 1: Conditional DCGAN with Spectral Normalization

# %%
# !pip install tensorflow-addons pandas matplotlib seaborn

# %%
import os
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

from IPython import display
from tensorflow.data import Dataset

from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Conv2DTranspose, Embedding, Reshape, Flatten, Dropout, BatchNormalization, ReLU, LeakyReLU, MaxPooling2D, Concatenate
from tensorflow_addons.layers import SpectralNormalization

from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import Callback
from tensorflow.keras.utils import plot_model

import warnings
warnings.filterwarnings('ignore')

# %%
sns.set(rc={'figure.dpi': 120})
sns.set_style('whitegrid')

# %%
# set gpu memory growth
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# set random seed
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# ## Load Dataset

# %%
FILE_PATH = '.\data\cifar10.tfrecords'
dataset = Dataset.load(FILE_PATH)
print(dataset.element_spec)
# Out:
# (TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.uint8, name=None))

# %% [markdown]
# ## Defining Generator

# %%
def create_generator(latent_dim):
    # foundation for label embeedded input
    label_input = Input(shape=(1,), name='label_input')
    label_embedding = Embedding(10, 10, name='label_embedding')(label_input)
    
    # linear activation
    label_embedding = Dense(4 * 4, name='label_dense')(label_embedding)

    # reshape to additional channel
    label_embedding = Reshape((4, 4, 1), name='label_reshape')(label_embedding)
    assert label_embedding.shape == (None, 4, 4, 1)

    # foundation for 4x4 image input
    noise_input = Input(shape=(latent_dim,), name='noise_input')
    noise_dense = Dense(4 * 4 * 128, name='noise_dense')(noise_input)
    noise_dense = ReLU(name='noise_relu')(noise_dense)
    noise_reshape = Reshape((4, 4, 128), name='noise_reshape')(noise_dense)
    assert noise_reshape.shape == (None, 4, 4, 128)

    # concatenate label embedding and image to produce 129-channel output
    concat = keras.layers.Concatenate(name='concatenate')([noise_reshape, label_embedding])
    assert concat.shape == (None, 4, 4, 129)

    # upsample to 8x8
    conv1 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', name='conv1')(concat)
    assert conv1.shape == (None, 8, 8, 128)
    conv1 = ReLU(name='conv1_relu')(conv1)

    # upsample to 16x16
    conv2 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', name='conv2')(conv1)
    assert conv2.shape == (None, 16, 16, 128)
    conv2 = ReLU(name='conv2_relu')(conv2)

    # upsample to 32x32
    conv3 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', name='conv3')(conv2)
    assert conv3.shape == (None, 32, 32, 128)
    conv3 = ReLU(name='conv3_relu')(conv3)

    # output 32x32x3
    output = Conv2D(3, (3, 3), activation='tanh', padding='same', name='output')(conv3)
    assert output.shape == (None, 32, 32, 3)

    model = Model(inputs=[noise_input, label_input], outputs=output, name='generator')

    return model

# %%
create_generator(latent_dim=128).summary()
# Out:
# Model: "generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  noise_input (InputLayer)       [(None, 128)]        0           []
#
#  label_input (InputLayer)       [(None, 1)]          0           []
#
#  noise_dense (Dense)            (None, 2048)         264192      ['noise_input[0][0]']
#
#  label_embedding (Embedding)    (None, 1, 10)        100         ['label_input[0][0]']
#
#  noise_relu (ReLU)              (None, 2048)         0           ['noise_dense[0][0]']
#
#  label_dense (Dense)            (None, 1, 16)        176         ['label_embedding[0][0]']
#
#  noise_reshape (Reshape)        (None, 4, 4, 128)    0           ['noise_relu[0][0]']
#
#  label_reshape (Reshape)        (None, 4, 4, 1)      0           ['label_dense[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 129)    0           ['noise_reshape[0][0]',
#                                                                   'label_reshape[0][0]']
#
#  conv1 (Conv2DTranspose)        (None, 8, 8, 128)    264320      ['concatenate[0][0]']
#
#  conv1_relu (ReLU)              (None, 8, 8, 128)    0           ['conv1[0][0]']
#
#  conv2 (Conv2DTranspose)        (None, 16, 16, 128)  262272      ['conv1_relu[0][0]']
#
#  conv2_relu (ReLU)              (None, 16, 16, 128)  0           ['conv2[0][0]']
#
#  conv3 (Conv2DTranspose)        (None, 32, 32, 128)  262272      ['conv2_relu[0][0]']
#
#  conv3_relu (ReLU)              (None, 32, 32, 128)  0           ['conv3[0][0]']
#
#  output (Conv2D)                (None, 32, 32, 3)    3459        ['conv3_relu[0][0]']
#
# ==================================================================================================
# Total params: 1,056,791
# Trainable params: 1,056,791
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# visualize generator
# plot_model(generator, show_shapes=True, to_file='images\model_architecture\Conditional_DCGAN\generator.png')
# generator_img = mpimg.imread('images\model_architecture\Conditional_DCGAN\generator.png')

# plt.figure(figsize=(20, 20))
# imgplot = plt.imshow(generator_img)
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Defining Discriminator

# %%
def create_discriminator():
    # foundation for label embeedded input
    label_input = Input(shape=(1,), name='label_input')
    label_embedding = Embedding(10, 10, name='label_embedding')(label_input)
    
    # linear activation
    label_embedding = Dense(32 * 32, name='label_dense')(label_embedding)
    
    # reshape to additional channel
    label_embedding = Reshape((32, 32, 1), name='label_reshape')(label_embedding)
    assert label_embedding.shape == (None, 32, 32, 1)

    # foundation for 32x32 image input
    image_input = Input(shape=(32, 32, 3), name='image_input')

    # concatenate label embedding and image to produce 129-channel input
    concat = keras.layers.Concatenate(name='concatenate')([image_input, label_embedding])
    assert concat.shape == (None, 32, 32, 4)

    # downsample to 16x16
    conv1 = SpectralNormalization(Conv2D(128, kernel_size=3, strides=2, padding='same', name='conv1'))
    conv1 = conv1(concat)
    assert conv1.shape == (None, 16, 16, 128)
    conv1 = LeakyReLU(alpha=0.2, name='conv1_leaky_relu')(conv1)
    
    # downsample to 8x8
    conv2 = SpectralNormalization(Conv2D(128, kernel_size=3, strides=2, padding='same', name='conv2'))
    conv2 = conv2(conv1)
    assert conv2.shape == (None, 8, 8, 128)
    conv2 = LeakyReLU(alpha=0.2, name='conv2_leaky_relu')(conv2)
    
    # downsample to 4x4
    conv3 = SpectralNormalization(Conv2D(128, kernel_size=3, strides=2, padding='same', name='conv3'))
    conv3 = conv3(conv2)
    assert conv3.shape == (None, 4, 4, 128)
    conv3 = LeakyReLU(alpha=0.2, name='conv3_leaky_relu')(conv3)

    # flatten feature maps
    flat = Flatten(name='flatten')(conv3)
    
    output = Dense(units=1, activation='sigmoid', name='output')(flat)

    model = Model(inputs=[image_input, label_input], outputs=output, name='discriminator')

    return model

# %%
create_discriminator().summary()
# Out:
# Model: "discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  label_input (InputLayer)       [(None, 1)]          0           []
#
#  label_embedding (Embedding)    (None, 1, 10)        100         ['label_input[0][0]']
#
#  label_dense (Dense)            (None, 1, 1024)      11264       ['label_embedding[0][0]']
#
#  image_input (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  label_reshape (Reshape)        (None, 32, 32, 1)    0           ['label_dense[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 4)    0           ['image_input[0][0]',
#                                                                   'label_reshape[0][0]']
#
#  spectral_normalization (Spectr  (None, 16, 16, 128)  4864       ['concatenate[0][0]']
#  alNormalization)
#
#  conv1_leaky_relu (LeakyReLU)   (None, 16, 16, 128)  0           ['spectral_normalization[0][0]']
#
#  spectral_normalization_1 (Spec  (None, 8, 8, 128)   147712      ['conv1_leaky_relu[0][0]']
#  tralNormalization)
#
#  conv2_leaky_relu (LeakyReLU)   (None, 8, 8, 128)    0           ['spectral_normalization_1[0][0]'
#                                                                  ]
#
#  spectral_normalization_2 (Spec  (None, 4, 4, 128)   147712      ['conv2_leaky_relu[0][0]']
#  tralNormalization)
#
#  conv3_leaky_relu (LeakyReLU)   (None, 4, 4, 128)    0           ['spectral_normalization_2[0][0]'
#                                                                  ]
#
#  flatten (Flatten)              (None, 2048)         0           ['conv3_leaky_relu[0][0]']
#
#  output (Dense)                 (None, 1)            2049        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 313,701
# Trainable params: 313,317
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
# visualize discriminator
# plot_model(discriminator, show_shapes=True, to_file='images\model_architecture\Conditional_DCGAN\discriminator.png')
# discriminator_img = mpimg.imread('images\model_architecture\Conditional_DCGAN\discriminator.png')

# plt.figure(figsize=(10, 10))
# imgplot = plt.imshow(discriminator_img)
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Defining cDCGAN

# %%
class ConditionalDCGAN(Model):
    def __init__(self, generator, discriminator, latent_dim):
        super(ConditionalDCGAN, self).__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(ConditionalDCGAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        self.g_loss_metric = keras.metrics.Mean(name='g_loss')
        self.d_real_loss_metric = keras.metrics.Mean(name='d_real_loss')
        self.d_fake_loss_metric = keras.metrics.Mean(name='d_fake_loss')
        self.d_acc_metric = keras.metrics.BinaryAccuracy(name='d_acc')

    @property
    def metrics(self):
        return [self.g_loss_metric, self.d_real_loss_metric, self.d_fake_loss_metric, self.d_acc_metric]

    def train_step(self, data):
        real_images, class_labels = data
        class_labels = tf.cast(class_labels, 'int32')
        batch_size = tf.shape(real_images)[0]

        # train discriminator
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        random_class_labels = tf.random.uniform(shape=(batch_size, 1), minval=0, maxval=10, dtype='int32')

        fake_labels = tf.zeros((batch_size, 1))  # (batch_size, 1)
        real_labels = tf.ones((batch_size, 1))  # (batch_size, 1)

        # freeze generator
        self.discriminator.trainable = True
        self.generator.trainable = False
    
        with tf.GradientTape() as disc_tape:
            disc_tape.watch(self.discriminator.trainable_variables)
            generated_images = self.generator([random_latent_vectors, random_class_labels], training=True)
            real_output = self.discriminator([real_images, class_labels], training=True)
            fake_output = self.discriminator([generated_images, random_class_labels], training=True)
            d_loss_real = self.loss_fn(real_labels, real_output)
            d_loss_fake = self.loss_fn(fake_labels, fake_output)
            d_loss = d_loss_real + d_loss_fake  # log(D(x)) + log(1 - D(G(z))
        
        disc_grads = disc_tape.gradient(d_loss, self.discriminator.trainable_variables)
        self.d_optimizer.apply_gradients(zip(disc_grads, self.discriminator.trainable_variables))

        # train the generator
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        random_class_labels = tf.random.uniform(shape=(batch_size, 1), minval=0, maxval=10, dtype='int32')
        misleading_labels = tf.ones((batch_size, 1))

        # freeze discriminator
        self.discriminator.trainable = False
        self.generator.trainable = True

        with tf.GradientTape() as gen_tape:
            gen_tape.watch(self.generator.trainable_variables)
            generated_images = self.generator([random_latent_vectors, random_class_labels], training=True)
            pred_on_fake = self.discriminator([generated_images, random_class_labels], training=True)
            # negative log probability of the discriminator making the correct choice
            g_loss = self.loss_fn(misleading_labels, pred_on_fake)  # maximize log(D(G(z))) = minimize -log(1 - D(G(z)))
        
        gen_grads = gen_tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(zip(gen_grads, self.generator.trainable_variables))

        # update metrics
        self.g_loss_metric.update_state(g_loss)
        self.d_real_loss_metric.update_state(d_loss_real)
        self.d_fake_loss_metric.update_state(d_loss_fake)
        self.d_acc_metric.update_state(real_labels, real_output)

        return {
            'g_loss': self.g_loss_metric.result(),
            'd_real_loss': self.d_real_loss_metric.result(),
            'd_fake_loss': self.d_fake_loss_metric.result(),
            'd_acc': self.d_acc_metric.result()
        }

# %%
class GANMonitor(Callback):
    def __init__(self, latent_dim, label_map):
        self.latent_dim = latent_dim
        self.label_map = label_map

    def on_epoch_end(self, epoch, logs=None):
        # plot 100 generated images and save weights every 10 epochs
        latent_vectors = tf.random.normal(shape=(100, self.latent_dim))
        class_labels = tf.reshape(tf.range(10), shape=(10, 1))
        class_labels = tf.tile(class_labels, multiples=(1, 10))
        class_labels = tf.reshape(class_labels, shape=(100, 1))

        generated_images = self.model.generator([latent_vectors, class_labels], training=False)
        generated_images = (generated_images + 1) / 2

        if not os.path.exists('./assets/sngan'):
            os.makedirs('./assets/sngan')

        if not os.path.exists('./images/sngan_images'):
            os.makedirs('./images/sngan_images')

        if (epoch + 1) % 10 == 0:
            if not os.path.exists(f'./assets/sngan/epoch_{epoch + 1}'):
                os.makedirs(f'./assets/sngan/epoch_{epoch + 1}')
                self.model.generator.save_weights(f'./assets/sngan/epoch_{epoch + 1}/generator_weights_epoch_{epoch + 1}.h5')
                self.model.discriminator.save_weights(f'./assets/sngan/epoch_{epoch + 1}/discriminator_weights_epoch_{epoch + 1}.h5')
                print(f'\n\nSaving weights at epoch {epoch + 1}\n')

            fig, axes = plt.subplots(10, 10, figsize=(20, 20))
            axes = axes.flatten()

            for i, ax in enumerate(axes):
                ax.imshow(generated_images[i])
                ax.set_title(self.label_map[class_labels[i].numpy().item()], fontsize=16)
                ax.axis('off')

            plt.tight_layout()
            plt.savefig(f'./images/sngan_images/generated_img_{epoch + 1}.png')
            plt.close()

# %% [markdown]
# ## Training SNGAN

# %%
EPOCHS = 1000
LATENT_DIM = 128    
LEARNING_RATE = 2e-4
BETA_1 = 0.5
LABEL_SMOOTHING = 0.1

label_map = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck'
}

callbacks = [GANMonitor(LATENT_DIM, label_map)]

generator = create_generator(LATENT_DIM)
discriminator = create_discriminator()
cdcgan = ConditionalDCGAN(generator, discriminator, latent_dim=LATENT_DIM)
cdcgan.compile(
    g_optimizer=Adam(learning_rate=LEARNING_RATE, beta_1=BETA_1),
    d_optimizer=Adam(learning_rate=LEARNING_RATE, beta_1=BETA_1),
    loss_fn=BinaryCrossentropy(label_smoothing=LABEL_SMOOTHING)
)

# %%
# %%time
history = cdcgan.fit(dataset, epochs=EPOCHS, callbacks=callbacks, use_multiprocessing=True)
# Out:
# Epoch 1/1000
# 467/467 [==============================] - 51s 75ms/step - g_loss: 1.4676 - d_real_loss: 0.5037 - d_fake_loss: 0.5167 - d_acc: 0.7794
# Epoch 2/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 1.6381 - d_real_loss: 0.5385 - d_fake_loss: 0.4394 - d_acc: 0.7402
# Epoch 3/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 1.6231 - d_real_loss: 0.5010 - d_fake_loss: 0.4108 - d_acc: 0.7964
# Epoch 4/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 1.3774 - d_real_loss: 0.5501 - d_fake_loss: 0.4670 - d_acc: 0.7484
# Epoch 5/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.3845 - d_real_loss: 0.5533 - d_fake_loss: 0.4710 - d_acc: 0.7418
# Epoch 6/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.1832 - d_real_loss: 0.5643 - d_fake_loss: 0.5330 - d_acc: 0.7483
# Epoch 7/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 1.2871 - d_real_loss: 0.5527 - d_fake_loss: 0.5193 - d_acc: 0.7523
# Epoch 8/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 1.3196 - d_real_loss: 0.5410 - d_fake_loss: 0.5053 - d_acc: 0.7693
# Epoch 9/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.3244 - d_real_loss: 0.5299 - d_fake_loss: 0.4922 - d_acc: 0.7738
# Epoch 10/1000
# 467/467 [==============================] - 39s 84ms/step - g_loss: 1.2786 - d_real_loss: 0.5510 - d_fake_loss: 0.5105 - d_acc: 0.7574
# Epoch 11/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.2520 - d_real_loss: 0.5620 - d_fake_loss: 0.5343 - d_acc: 0.7420
# Epoch 12/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.1656 - d_real_loss: 0.5706 - d_fake_loss: 0.5537 - d_acc: 0.7333
# Epoch 13/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.1353 - d_real_loss: 0.5624 - d_fake_loss: 0.5456 - d_acc: 0.7476
# Epoch 14/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 1.0910 - d_real_loss: 0.5767 - d_fake_loss: 0.5675 - d_acc: 0.7347
# Epoch 15/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.0790 - d_real_loss: 0.5786 - d_fake_loss: 0.5676 - d_acc: 0.7270
# Epoch 16/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 1.0984 - d_real_loss: 0.5822 - d_fake_loss: 0.5699 - d_acc: 0.7219
# Epoch 17/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.0578 - d_real_loss: 0.5846 - d_fake_loss: 0.5755 - d_acc: 0.7197
# Epoch 18/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.0642 - d_real_loss: 0.5898 - d_fake_loss: 0.5788 - d_acc: 0.7157
# Epoch 19/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 1.0376 - d_real_loss: 0.5830 - d_fake_loss: 0.5723 - d_acc: 0.7225
# Epoch 20/1000
# 467/467 [==============================] - 39s 84ms/step - g_loss: 1.0307 - d_real_loss: 0.5952 - d_fake_loss: 0.5840 - d_acc: 0.7031
# Epoch 21/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.9999 - d_real_loss: 0.6095 - d_fake_loss: 0.5972 - d_acc: 0.6841
# Epoch 22/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.9589 - d_real_loss: 0.6183 - d_fake_loss: 0.6082 - d_acc: 0.6791
# Epoch 23/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.9559 - d_real_loss: 0.6248 - d_fake_loss: 0.6149 - d_acc: 0.6705
# Epoch 24/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.9421 - d_real_loss: 0.6282 - d_fake_loss: 0.6178 - d_acc: 0.6647
# Epoch 25/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.9316 - d_real_loss: 0.6256 - d_fake_loss: 0.6143 - d_acc: 0.6683
# Epoch 26/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.9397 - d_real_loss: 0.6298 - d_fake_loss: 0.6166 - d_acc: 0.6608
# Epoch 27/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.9481 - d_real_loss: 0.6344 - d_fake_loss: 0.6185 - d_acc: 0.6516
# Epoch 28/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.9348 - d_real_loss: 0.6379 - d_fake_loss: 0.6252 - d_acc: 0.6453
# Epoch 29/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.9121 - d_real_loss: 0.6339 - d_fake_loss: 0.6227 - d_acc: 0.6495
# Epoch 30/1000
# 467/467 [==============================] - 39s 83ms/step - g_loss: 0.9195 - d_real_loss: 0.6366 - d_fake_loss: 0.6237 - d_acc: 0.6461
# Epoch 31/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.9108 - d_real_loss: 0.6383 - d_fake_loss: 0.6277 - d_acc: 0.6439
# Epoch 32/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.9060 - d_real_loss: 0.6405 - d_fake_loss: 0.6277 - d_acc: 0.6376
# Epoch 33/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8883 - d_real_loss: 0.6402 - d_fake_loss: 0.6307 - d_acc: 0.6395
# Epoch 34/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8876 - d_real_loss: 0.6424 - d_fake_loss: 0.6333 - d_acc: 0.6348
# Epoch 35/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.8727 - d_real_loss: 0.6419 - d_fake_loss: 0.6340 - d_acc: 0.6387
# Epoch 36/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8714 - d_real_loss: 0.6479 - d_fake_loss: 0.6371 - d_acc: 0.6257
# Epoch 37/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8630 - d_real_loss: 0.6470 - d_fake_loss: 0.6392 - d_acc: 0.6288
# Epoch 38/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8575 - d_real_loss: 0.6478 - d_fake_loss: 0.6408 - d_acc: 0.6293
# Epoch 39/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8610 - d_real_loss: 0.6508 - d_fake_loss: 0.6423 - d_acc: 0.6253
# Epoch 40/1000
# 467/467 [==============================] - 39s 83ms/step - g_loss: 0.8483 - d_real_loss: 0.6497 - d_fake_loss: 0.6430 - d_acc: 0.6276
# Epoch 41/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8403 - d_real_loss: 0.6510 - d_fake_loss: 0.6437 - d_acc: 0.6228
# Epoch 42/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8500 - d_real_loss: 0.6542 - d_fake_loss: 0.6480 - d_acc: 0.6143
# Epoch 43/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8346 - d_real_loss: 0.6541 - d_fake_loss: 0.6476 - d_acc: 0.6209
# Epoch 44/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8408 - d_real_loss: 0.6537 - d_fake_loss: 0.6475 - d_acc: 0.6155
# Epoch 45/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8329 - d_real_loss: 0.6541 - d_fake_loss: 0.6479 - d_acc: 0.6198
# Epoch 46/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8363 - d_real_loss: 0.6559 - d_fake_loss: 0.6488 - d_acc: 0.6149
# Epoch 47/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8317 - d_real_loss: 0.6558 - d_fake_loss: 0.6496 - d_acc: 0.6150
# Epoch 48/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8300 - d_real_loss: 0.6562 - d_fake_loss: 0.6504 - d_acc: 0.6123
# Epoch 49/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8228 - d_real_loss: 0.6561 - d_fake_loss: 0.6496 - d_acc: 0.6167
# Epoch 50/1000
# 467/467 [==============================] - 39s 83ms/step - g_loss: 0.8283 - d_real_loss: 0.6598 - d_fake_loss: 0.6532 - d_acc: 0.6070
# Epoch 51/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8172 - d_real_loss: 0.6574 - d_fake_loss: 0.6510 - d_acc: 0.6100
# Epoch 52/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8123 - d_real_loss: 0.6566 - d_fake_loss: 0.6515 - d_acc: 0.6132
# Epoch 53/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8180 - d_real_loss: 0.6585 - d_fake_loss: 0.6530 - d_acc: 0.6088
# Epoch 54/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8238 - d_real_loss: 0.6591 - d_fake_loss: 0.6529 - d_acc: 0.6083
# Epoch 55/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8161 - d_real_loss: 0.6570 - d_fake_loss: 0.6511 - d_acc: 0.6105
# Epoch 56/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8196 - d_real_loss: 0.6585 - d_fake_loss: 0.6530 - d_acc: 0.6068
# Epoch 57/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8193 - d_real_loss: 0.6590 - d_fake_loss: 0.6535 - d_acc: 0.6072
# Epoch 58/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8182 - d_real_loss: 0.6595 - d_fake_loss: 0.6540 - d_acc: 0.6075
# Epoch 59/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8133 - d_real_loss: 0.6574 - d_fake_loss: 0.6513 - d_acc: 0.6095
# Epoch 60/1000
# 467/467 [==============================] - 39s 83ms/step - g_loss: 0.8116 - d_real_loss: 0.6571 - d_fake_loss: 0.6518 - d_acc: 0.6112
# Epoch 61/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8151 - d_real_loss: 0.6580 - d_fake_loss: 0.6528 - d_acc: 0.6098
# Epoch 62/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.8076 - d_real_loss: 0.6575 - d_fake_loss: 0.6524 - d_acc: 0.6099
# Epoch 63/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8137 - d_real_loss: 0.6591 - d_fake_loss: 0.6537 - d_acc: 0.6087
# Epoch 64/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.8226 - d_real_loss: 0.6621 - d_fake_loss: 0.6577 - d_acc: 0.6050
# Epoch 65/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.8073 - d_real_loss: 0.6615 - d_fake_loss: 0.6559 - d_acc: 0.6028
# Epoch 66/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.8001 - d_real_loss: 0.6582 - d_fake_loss: 0.6540 - d_acc: 0.6097
# Epoch 67/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.8028 - d_real_loss: 0.6592 - d_fake_loss: 0.6546 - d_acc: 0.6089
# Epoch 68/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.8035 - d_real_loss: 0.6604 - d_fake_loss: 0.6554 - d_acc: 0.6041
# Epoch 69/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.8040 - d_real_loss: 0.6618 - d_fake_loss: 0.6567 - d_acc: 0.6041
# Epoch 70/1000
# 467/467 [==============================] - 38s 82ms/step - g_loss: 0.8020 - d_real_loss: 0.6621 - d_fake_loss: 0.6580 - d_acc: 0.6022
# Epoch 71/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7959 - d_real_loss: 0.6624 - d_fake_loss: 0.6578 - d_acc: 0.6009
# Epoch 72/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7966 - d_real_loss: 0.6630 - d_fake_loss: 0.6590 - d_acc: 0.5997
# Epoch 73/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7953 - d_real_loss: 0.6637 - d_fake_loss: 0.6594 - d_acc: 0.6027
# Epoch 74/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7997 - d_real_loss: 0.6642 - d_fake_loss: 0.6599 - d_acc: 0.5981
# Epoch 75/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7925 - d_real_loss: 0.6640 - d_fake_loss: 0.6593 - d_acc: 0.5992
# Epoch 76/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7980 - d_real_loss: 0.6655 - d_fake_loss: 0.6605 - d_acc: 0.5972
# Epoch 77/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7919 - d_real_loss: 0.6638 - d_fake_loss: 0.6599 - d_acc: 0.5988
# Epoch 78/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7899 - d_real_loss: 0.6641 - d_fake_loss: 0.6600 - d_acc: 0.5960
# Epoch 79/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7923 - d_real_loss: 0.6649 - d_fake_loss: 0.6608 - d_acc: 0.5974
# Epoch 80/1000
# 467/467 [==============================] - 39s 83ms/step - g_loss: 0.7943 - d_real_loss: 0.6651 - d_fake_loss: 0.6610 - d_acc: 0.5943
# Epoch 81/1000
# 467/467 [==============================] - 33s 69ms/step - g_loss: 0.7892 - d_real_loss: 0.6642 - d_fake_loss: 0.6603 - d_acc: 0.5990
# Epoch 82/1000
# 467/467 [==============================] - 32s 70ms/step - g_loss: 0.7955 - d_real_loss: 0.6661 - d_fake_loss: 0.6622 - d_acc: 0.5938
# Epoch 83/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7885 - d_real_loss: 0.6647 - d_fake_loss: 0.6608 - d_acc: 0.5962
# Epoch 84/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7908 - d_real_loss: 0.6646 - d_fake_loss: 0.6607 - d_acc: 0.5987
# Epoch 85/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7921 - d_real_loss: 0.6658 - d_fake_loss: 0.6615 - d_acc: 0.5935
# Epoch 86/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7870 - d_real_loss: 0.6645 - d_fake_loss: 0.6611 - d_acc: 0.5983
# Epoch 87/1000
# 467/467 [==============================] - 32s 70ms/step - g_loss: 0.7896 - d_real_loss: 0.6650 - d_fake_loss: 0.6608 - d_acc: 0.5985
# Epoch 88/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7895 - d_real_loss: 0.6671 - d_fake_loss: 0.6632 - d_acc: 0.5935
# Epoch 89/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7848 - d_real_loss: 0.6652 - d_fake_loss: 0.6614 - d_acc: 0.5958
# Epoch 90/1000
# 467/467 [==============================] - 38s 82ms/step - g_loss: 0.7862 - d_real_loss: 0.6648 - d_fake_loss: 0.6616 - d_acc: 0.5954
# Epoch 91/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7875 - d_real_loss: 0.6654 - d_fake_loss: 0.6616 - d_acc: 0.5932
# Epoch 92/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7855 - d_real_loss: 0.6654 - d_fake_loss: 0.6617 - d_acc: 0.5935
# Epoch 93/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7887 - d_real_loss: 0.6660 - d_fake_loss: 0.6617 - d_acc: 0.5923
# Epoch 94/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7923 - d_real_loss: 0.6670 - d_fake_loss: 0.6641 - d_acc: 0.5908
# Epoch 95/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7868 - d_real_loss: 0.6650 - d_fake_loss: 0.6613 - d_acc: 0.5982
# Epoch 96/1000
# 467/467 [==============================] - 32s 70ms/step - g_loss: 0.7862 - d_real_loss: 0.6656 - d_fake_loss: 0.6617 - d_acc: 0.5944
# Epoch 97/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7872 - d_real_loss: 0.6655 - d_fake_loss: 0.6621 - d_acc: 0.5968
# Epoch 98/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7859 - d_real_loss: 0.6655 - d_fake_loss: 0.6613 - d_acc: 0.5954
# Epoch 99/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7865 - d_real_loss: 0.6657 - d_fake_loss: 0.6620 - d_acc: 0.5924
# Epoch 100/1000
# 467/467 [==============================] - 38s 82ms/step - g_loss: 0.7877 - d_real_loss: 0.6652 - d_fake_loss: 0.6616 - d_acc: 0.5922
# Epoch 101/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7855 - d_real_loss: 0.6657 - d_fake_loss: 0.6621 - d_acc: 0.5958
# Epoch 102/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7873 - d_real_loss: 0.6672 - d_fake_loss: 0.6628 - d_acc: 0.5910
# Epoch 103/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7849 - d_real_loss: 0.6659 - d_fake_loss: 0.6622 - d_acc: 0.5942
# Epoch 104/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7883 - d_real_loss: 0.6660 - d_fake_loss: 0.6621 - d_acc: 0.5904
# Epoch 105/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7875 - d_real_loss: 0.6659 - d_fake_loss: 0.6620 - d_acc: 0.5988
# Epoch 106/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7849 - d_real_loss: 0.6656 - d_fake_loss: 0.6620 - d_acc: 0.5978
# Epoch 107/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7845 - d_real_loss: 0.6662 - d_fake_loss: 0.6621 - d_acc: 0.5944
# Epoch 108/1000
# 467/467 [==============================] - 33s 70ms/step - g_loss: 0.7869 - d_real_loss: 0.6672 - d_fake_loss: 0.6633 - d_acc: 0.5908
# Epoch 109/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7863 - d_real_loss: 0.6663 - d_fake_loss: 0.6627 - d_acc: 0.5955
# Epoch 110/1000
# 467/467 [==============================] - 36s 78ms/step - g_loss: 0.7820 - d_real_loss: 0.6660 - d_fake_loss: 0.6624 - d_acc: 0.5970
# Epoch 111/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7828 - d_real_loss: 0.6662 - d_fake_loss: 0.6624 - d_acc: 0.5915
# Epoch 112/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7809 - d_real_loss: 0.6666 - d_fake_loss: 0.6633 - d_acc: 0.5935
# Epoch 113/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7834 - d_real_loss: 0.6679 - d_fake_loss: 0.6644 - d_acc: 0.5886
# Epoch 114/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7813 - d_real_loss: 0.6677 - d_fake_loss: 0.6646 - d_acc: 0.5896
# Epoch 115/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7792 - d_real_loss: 0.6678 - d_fake_loss: 0.6646 - d_acc: 0.5892
# Epoch 116/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7784 - d_real_loss: 0.6680 - d_fake_loss: 0.6646 - d_acc: 0.5879
# Epoch 117/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7803 - d_real_loss: 0.6687 - d_fake_loss: 0.6656 - d_acc: 0.5878
# Epoch 118/1000
# 467/467 [==============================] - 32s 70ms/step - g_loss: 0.7807 - d_real_loss: 0.6683 - d_fake_loss: 0.6644 - d_acc: 0.5859
# Epoch 119/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7757 - d_real_loss: 0.6671 - d_fake_loss: 0.6644 - d_acc: 0.5912
# Epoch 120/1000
# 467/467 [==============================] - 39s 83ms/step - g_loss: 0.7814 - d_real_loss: 0.6686 - d_fake_loss: 0.6649 - d_acc: 0.5918
# Epoch 121/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7774 - d_real_loss: 0.6686 - d_fake_loss: 0.6652 - d_acc: 0.5900
# Epoch 122/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7796 - d_real_loss: 0.6685 - d_fake_loss: 0.6654 - d_acc: 0.5880
# Epoch 123/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7776 - d_real_loss: 0.6697 - d_fake_loss: 0.6663 - d_acc: 0.5853
# Epoch 124/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7763 - d_real_loss: 0.6684 - d_fake_loss: 0.6657 - d_acc: 0.5879
# Epoch 125/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7775 - d_real_loss: 0.6684 - d_fake_loss: 0.6655 - d_acc: 0.5886
# Epoch 126/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7757 - d_real_loss: 0.6692 - d_fake_loss: 0.6657 - d_acc: 0.5875
# Epoch 127/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7776 - d_real_loss: 0.6691 - d_fake_loss: 0.6667 - d_acc: 0.5869
# Epoch 128/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7758 - d_real_loss: 0.6698 - d_fake_loss: 0.6664 - d_acc: 0.5847
# Epoch 129/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7744 - d_real_loss: 0.6694 - d_fake_loss: 0.6665 - d_acc: 0.5871
# Epoch 130/1000
# 467/467 [==============================] - 40s 85ms/step - g_loss: 0.7754 - d_real_loss: 0.6691 - d_fake_loss: 0.6668 - d_acc: 0.5863
# Epoch 131/1000
# 467/467 [==============================] - 34s 71ms/step - g_loss: 0.7752 - d_real_loss: 0.6700 - d_fake_loss: 0.6669 - d_acc: 0.5867
# Epoch 132/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7725 - d_real_loss: 0.6701 - d_fake_loss: 0.6665 - d_acc: 0.5867
# Epoch 133/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7736 - d_real_loss: 0.6706 - d_fake_loss: 0.6676 - d_acc: 0.5849
# Epoch 134/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7726 - d_real_loss: 0.6697 - d_fake_loss: 0.6676 - d_acc: 0.5846
# Epoch 135/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7730 - d_real_loss: 0.6703 - d_fake_loss: 0.6672 - d_acc: 0.5836
# Epoch 136/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7708 - d_real_loss: 0.6701 - d_fake_loss: 0.6676 - d_acc: 0.5844
# Epoch 137/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7729 - d_real_loss: 0.6708 - d_fake_loss: 0.6683 - d_acc: 0.5847
# Epoch 138/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7701 - d_real_loss: 0.6708 - d_fake_loss: 0.6684 - d_acc: 0.5826
# Epoch 139/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7709 - d_real_loss: 0.6712 - d_fake_loss: 0.6684 - d_acc: 0.5824
# Epoch 140/1000
# 467/467 [==============================] - 39s 84ms/step - g_loss: 0.7738 - d_real_loss: 0.6707 - d_fake_loss: 0.6683 - d_acc: 0.5821
# Epoch 141/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7710 - d_real_loss: 0.6708 - d_fake_loss: 0.6682 - d_acc: 0.5843
# Epoch 142/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7700 - d_real_loss: 0.6709 - d_fake_loss: 0.6684 - d_acc: 0.5840
# Epoch 143/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7741 - d_real_loss: 0.6721 - d_fake_loss: 0.6692 - d_acc: 0.5806
# Epoch 144/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7712 - d_real_loss: 0.6717 - d_fake_loss: 0.6688 - d_acc: 0.5827
# Epoch 145/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7686 - d_real_loss: 0.6714 - d_fake_loss: 0.6688 - d_acc: 0.5845
# Epoch 146/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7658 - d_real_loss: 0.6716 - d_fake_loss: 0.6689 - d_acc: 0.5816
# Epoch 147/1000
# 467/467 [==============================] - 35s 76ms/step - g_loss: 0.7686 - d_real_loss: 0.6721 - d_fake_loss: 0.6698 - d_acc: 0.5801
# Epoch 148/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7685 - d_real_loss: 0.6724 - d_fake_loss: 0.6702 - d_acc: 0.5803
# Epoch 149/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7682 - d_real_loss: 0.6723 - d_fake_loss: 0.6695 - d_acc: 0.5819
# Epoch 150/1000
# 467/467 [==============================] - 41s 87ms/step - g_loss: 0.7656 - d_real_loss: 0.6715 - d_fake_loss: 0.6693 - d_acc: 0.5813
# Epoch 151/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7675 - d_real_loss: 0.6730 - d_fake_loss: 0.6704 - d_acc: 0.5799
# Epoch 152/1000
# 467/467 [==============================] - 36s 76ms/step - g_loss: 0.7659 - d_real_loss: 0.6719 - d_fake_loss: 0.6697 - d_acc: 0.5844
# Epoch 153/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7659 - d_real_loss: 0.6719 - d_fake_loss: 0.6695 - d_acc: 0.5812
# Epoch 154/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7687 - d_real_loss: 0.6726 - d_fake_loss: 0.6702 - d_acc: 0.5786
# Epoch 155/1000
# 467/467 [==============================] - 35s 76ms/step - g_loss: 0.7669 - d_real_loss: 0.6724 - d_fake_loss: 0.6701 - d_acc: 0.5772
# Epoch 156/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7657 - d_real_loss: 0.6724 - d_fake_loss: 0.6701 - d_acc: 0.5781
# Epoch 157/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7644 - d_real_loss: 0.6731 - d_fake_loss: 0.6709 - d_acc: 0.5775
# Epoch 158/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7657 - d_real_loss: 0.6727 - d_fake_loss: 0.6705 - d_acc: 0.5771
# Epoch 159/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7648 - d_real_loss: 0.6732 - d_fake_loss: 0.6705 - d_acc: 0.5776
# Epoch 160/1000
# 467/467 [==============================] - 42s 89ms/step - g_loss: 0.7651 - d_real_loss: 0.6733 - d_fake_loss: 0.6710 - d_acc: 0.5807
# Epoch 161/1000
# 467/467 [==============================] - 35s 76ms/step - g_loss: 0.7648 - d_real_loss: 0.6736 - d_fake_loss: 0.6712 - d_acc: 0.5758
# Epoch 162/1000
# 467/467 [==============================] - 35s 76ms/step - g_loss: 0.7626 - d_real_loss: 0.6733 - d_fake_loss: 0.6716 - d_acc: 0.5756
# Epoch 163/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7637 - d_real_loss: 0.6733 - d_fake_loss: 0.6713 - d_acc: 0.5779
# Epoch 164/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7629 - d_real_loss: 0.6727 - d_fake_loss: 0.6707 - d_acc: 0.5823
# Epoch 165/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7665 - d_real_loss: 0.6740 - d_fake_loss: 0.6715 - d_acc: 0.5757
# Epoch 166/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7625 - d_real_loss: 0.6732 - d_fake_loss: 0.6712 - d_acc: 0.5784
# Epoch 167/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7638 - d_real_loss: 0.6737 - d_fake_loss: 0.6715 - d_acc: 0.5772
# Epoch 168/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7637 - d_real_loss: 0.6742 - d_fake_loss: 0.6721 - d_acc: 0.5751
# Epoch 169/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7617 - d_real_loss: 0.6743 - d_fake_loss: 0.6721 - d_acc: 0.5762
# Epoch 170/1000
# 467/467 [==============================] - 39s 84ms/step - g_loss: 0.7617 - d_real_loss: 0.6740 - d_fake_loss: 0.6721 - d_acc: 0.5757
# Epoch 171/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7640 - d_real_loss: 0.6737 - d_fake_loss: 0.6718 - d_acc: 0.5754
# Epoch 172/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7614 - d_real_loss: 0.6743 - d_fake_loss: 0.6722 - d_acc: 0.5759
# Epoch 173/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7624 - d_real_loss: 0.6739 - d_fake_loss: 0.6717 - d_acc: 0.5772
# Epoch 174/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7611 - d_real_loss: 0.6737 - d_fake_loss: 0.6715 - d_acc: 0.5778
# Epoch 175/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7620 - d_real_loss: 0.6742 - d_fake_loss: 0.6722 - d_acc: 0.5751
# Epoch 176/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7589 - d_real_loss: 0.6742 - d_fake_loss: 0.6723 - d_acc: 0.5778
# Epoch 177/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7629 - d_real_loss: 0.6750 - d_fake_loss: 0.6730 - d_acc: 0.5737
# Epoch 178/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7600 - d_real_loss: 0.6747 - d_fake_loss: 0.6728 - d_acc: 0.5728
# Epoch 179/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7594 - d_real_loss: 0.6747 - d_fake_loss: 0.6728 - d_acc: 0.5754
# Epoch 180/1000
# 467/467 [==============================] - 40s 86ms/step - g_loss: 0.7609 - d_real_loss: 0.6745 - d_fake_loss: 0.6724 - d_acc: 0.5736
# Epoch 181/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7590 - d_real_loss: 0.6748 - d_fake_loss: 0.6726 - d_acc: 0.5743
# Epoch 182/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7590 - d_real_loss: 0.6744 - d_fake_loss: 0.6726 - d_acc: 0.5747
# Epoch 183/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7622 - d_real_loss: 0.6751 - d_fake_loss: 0.6733 - d_acc: 0.5750
# Epoch 184/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7618 - d_real_loss: 0.6750 - d_fake_loss: 0.6730 - d_acc: 0.5759
# Epoch 185/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7585 - d_real_loss: 0.6747 - d_fake_loss: 0.6732 - d_acc: 0.5754
# Epoch 186/1000
# 467/467 [==============================] - 35s 76ms/step - g_loss: 0.7583 - d_real_loss: 0.6749 - d_fake_loss: 0.6727 - d_acc: 0.5745
# Epoch 187/1000
# 467/467 [==============================] - 36s 76ms/step - g_loss: 0.7592 - d_real_loss: 0.6751 - d_fake_loss: 0.6731 - d_acc: 0.5730
# Epoch 188/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7597 - d_real_loss: 0.6752 - d_fake_loss: 0.6734 - d_acc: 0.5745
# Epoch 189/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7589 - d_real_loss: 0.6751 - d_fake_loss: 0.6732 - d_acc: 0.5710
# Epoch 190/1000
# 467/467 [==============================] - 40s 87ms/step - g_loss: 0.7568 - d_real_loss: 0.6752 - d_fake_loss: 0.6731 - d_acc: 0.5757
# Epoch 191/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7566 - d_real_loss: 0.6753 - d_fake_loss: 0.6736 - d_acc: 0.5728
# Epoch 192/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7595 - d_real_loss: 0.6759 - d_fake_loss: 0.6738 - d_acc: 0.5723
# Epoch 193/1000
# 467/467 [==============================] - 35s 76ms/step - g_loss: 0.7588 - d_real_loss: 0.6764 - d_fake_loss: 0.6745 - d_acc: 0.5666
# Epoch 194/1000
# 467/467 [==============================] - 36s 78ms/step - g_loss: 0.7575 - d_real_loss: 0.6758 - d_fake_loss: 0.6738 - d_acc: 0.5703
# Epoch 195/1000
# 467/467 [==============================] - 37s 80ms/step - g_loss: 0.7541 - d_real_loss: 0.6752 - d_fake_loss: 0.6732 - d_acc: 0.5766
# Epoch 196/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7572 - d_real_loss: 0.6762 - d_fake_loss: 0.6742 - d_acc: 0.5713
# Epoch 197/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7566 - d_real_loss: 0.6765 - d_fake_loss: 0.6745 - d_acc: 0.5699
# Epoch 198/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7547 - d_real_loss: 0.6757 - d_fake_loss: 0.6739 - d_acc: 0.5757
# Epoch 199/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7568 - d_real_loss: 0.6755 - d_fake_loss: 0.6737 - d_acc: 0.5737
# Epoch 200/1000
# 467/467 [==============================] - 41s 88ms/step - g_loss: 0.7585 - d_real_loss: 0.6754 - d_fake_loss: 0.6735 - d_acc: 0.5711
# Epoch 201/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7561 - d_real_loss: 0.6762 - d_fake_loss: 0.6740 - d_acc: 0.5703
# Epoch 202/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7562 - d_real_loss: 0.6760 - d_fake_loss: 0.6745 - d_acc: 0.5712
# Epoch 203/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7565 - d_real_loss: 0.6759 - d_fake_loss: 0.6739 - d_acc: 0.5687
# Epoch 204/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7563 - d_real_loss: 0.6762 - d_fake_loss: 0.6743 - d_acc: 0.5708
# Epoch 205/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7564 - d_real_loss: 0.6758 - d_fake_loss: 0.6740 - d_acc: 0.5709
# Epoch 206/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7526 - d_real_loss: 0.6765 - d_fake_loss: 0.6746 - d_acc: 0.5694
# Epoch 207/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7543 - d_real_loss: 0.6768 - d_fake_loss: 0.6751 - d_acc: 0.5688
# Epoch 208/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7559 - d_real_loss: 0.6758 - d_fake_loss: 0.6739 - d_acc: 0.5706
# Epoch 209/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7571 - d_real_loss: 0.6768 - d_fake_loss: 0.6749 - d_acc: 0.5708
# Epoch 210/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7543 - d_real_loss: 0.6766 - d_fake_loss: 0.6749 - d_acc: 0.5715
#
# Saving weights at epoch 210
#
# 467/467 [==============================] - 40s 86ms/step - g_loss: 0.7543 - d_real_loss: 0.6766 - d_fake_loss: 0.6749 - d_acc: 0.5715
# Epoch 211/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7522 - d_real_loss: 0.6768 - d_fake_loss: 0.6751 - d_acc: 0.5693
# Epoch 212/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7530 - d_real_loss: 0.6771 - d_fake_loss: 0.6754 - d_acc: 0.5684
# Epoch 213/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7512 - d_real_loss: 0.6770 - d_fake_loss: 0.6752 - d_acc: 0.5702
# Epoch 214/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7528 - d_real_loss: 0.6773 - d_fake_loss: 0.6754 - d_acc: 0.5680
# Epoch 215/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7526 - d_real_loss: 0.6766 - d_fake_loss: 0.6754 - d_acc: 0.5710
# Epoch 216/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7524 - d_real_loss: 0.6770 - d_fake_loss: 0.6750 - d_acc: 0.5681
# Epoch 217/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7538 - d_real_loss: 0.6772 - d_fake_loss: 0.6754 - d_acc: 0.5689
# Epoch 218/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7529 - d_real_loss: 0.6770 - d_fake_loss: 0.6755 - d_acc: 0.5686
# Epoch 219/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7523 - d_real_loss: 0.6771 - d_fake_loss: 0.6753 - d_acc: 0.5709
# Epoch 220/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7528 - d_real_loss: 0.6775 - d_fake_loss: 0.6755 - d_acc: 0.5682
#
# Saving weights at epoch 220
#
# 467/467 [==============================] - 40s 85ms/step - g_loss: 0.7528 - d_real_loss: 0.6775 - d_fake_loss: 0.6755 - d_acc: 0.5682
# Epoch 221/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7513 - d_real_loss: 0.6771 - d_fake_loss: 0.6758 - d_acc: 0.5674
# Epoch 222/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7507 - d_real_loss: 0.6777 - d_fake_loss: 0.6758 - d_acc: 0.5661
# Epoch 223/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7523 - d_real_loss: 0.6780 - d_fake_loss: 0.6762 - d_acc: 0.5653
# Epoch 224/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7511 - d_real_loss: 0.6780 - d_fake_loss: 0.6762 - d_acc: 0.5689
# Epoch 225/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7504 - d_real_loss: 0.6779 - d_fake_loss: 0.6766 - d_acc: 0.5656
# Epoch 226/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7486 - d_real_loss: 0.6773 - d_fake_loss: 0.6761 - d_acc: 0.5667
# Epoch 227/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7491 - d_real_loss: 0.6775 - d_fake_loss: 0.6758 - d_acc: 0.5684
# Epoch 228/1000
# 467/467 [==============================] - 36s 77ms/step - g_loss: 0.7514 - d_real_loss: 0.6780 - d_fake_loss: 0.6762 - d_acc: 0.5630
# Epoch 229/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7506 - d_real_loss: 0.6778 - d_fake_loss: 0.6763 - d_acc: 0.5651
# Epoch 230/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7502 - d_real_loss: 0.6783 - d_fake_loss: 0.6764 - d_acc: 0.5661
#
# Saving weights at epoch 230
#
# 467/467 [==============================] - 40s 85ms/step - g_loss: 0.7502 - d_real_loss: 0.6783 - d_fake_loss: 0.6764 - d_acc: 0.5661
# Epoch 231/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7489 - d_real_loss: 0.6779 - d_fake_loss: 0.6762 - d_acc: 0.5663
# Epoch 232/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7497 - d_real_loss: 0.6779 - d_fake_loss: 0.6763 - d_acc: 0.5676
# Epoch 233/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7482 - d_real_loss: 0.6780 - d_fake_loss: 0.6764 - d_acc: 0.5649
# Epoch 234/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7508 - d_real_loss: 0.6785 - d_fake_loss: 0.6771 - d_acc: 0.5639
# Epoch 235/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7497 - d_real_loss: 0.6782 - d_fake_loss: 0.6769 - d_acc: 0.5638
# Epoch 236/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7480 - d_real_loss: 0.6780 - d_fake_loss: 0.6766 - d_acc: 0.5668
# Epoch 237/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7494 - d_real_loss: 0.6783 - d_fake_loss: 0.6769 - d_acc: 0.5679
# Epoch 238/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7471 - d_real_loss: 0.6785 - d_fake_loss: 0.6770 - d_acc: 0.5654
# Epoch 239/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7487 - d_real_loss: 0.6783 - d_fake_loss: 0.6766 - d_acc: 0.5647
# Epoch 240/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7476 - d_real_loss: 0.6784 - d_fake_loss: 0.6767 - d_acc: 0.5669
#
# Saving weights at epoch 240
#
# 467/467 [==============================] - 42s 89ms/step - g_loss: 0.7476 - d_real_loss: 0.6784 - d_fake_loss: 0.6767 - d_acc: 0.5669
# Epoch 241/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7493 - d_real_loss: 0.6781 - d_fake_loss: 0.6766 - d_acc: 0.5659
# Epoch 242/1000
# 467/467 [==============================] - 36s 77ms/step - g_loss: 0.7479 - d_real_loss: 0.6784 - d_fake_loss: 0.6766 - d_acc: 0.5650
# Epoch 243/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7494 - d_real_loss: 0.6790 - d_fake_loss: 0.6774 - d_acc: 0.5651
# Epoch 244/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7476 - d_real_loss: 0.6782 - d_fake_loss: 0.6766 - d_acc: 0.5659
# Epoch 245/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7478 - d_real_loss: 0.6783 - d_fake_loss: 0.6768 - d_acc: 0.5674
# Epoch 246/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7499 - d_real_loss: 0.6782 - d_fake_loss: 0.6768 - d_acc: 0.5647
# Epoch 247/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7472 - d_real_loss: 0.6777 - d_fake_loss: 0.6760 - d_acc: 0.5691
# Epoch 248/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7490 - d_real_loss: 0.6779 - d_fake_loss: 0.6762 - d_acc: 0.5675
# Epoch 249/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7475 - d_real_loss: 0.6778 - d_fake_loss: 0.6761 - d_acc: 0.5662
# Epoch 250/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7487 - d_real_loss: 0.6784 - d_fake_loss: 0.6770 - d_acc: 0.5640
#
# Saving weights at epoch 250
#
# 467/467 [==============================] - 40s 87ms/step - g_loss: 0.7487 - d_real_loss: 0.6784 - d_fake_loss: 0.6770 - d_acc: 0.5640
# Epoch 251/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7470 - d_real_loss: 0.6780 - d_fake_loss: 0.6765 - d_acc: 0.5653
# Epoch 252/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7470 - d_real_loss: 0.6783 - d_fake_loss: 0.6763 - d_acc: 0.5643
# Epoch 253/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7489 - d_real_loss: 0.6782 - d_fake_loss: 0.6770 - d_acc: 0.5661
# Epoch 254/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7486 - d_real_loss: 0.6781 - d_fake_loss: 0.6764 - d_acc: 0.5650
# Epoch 255/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7470 - d_real_loss: 0.6781 - d_fake_loss: 0.6763 - d_acc: 0.5670
# Epoch 256/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7468 - d_real_loss: 0.6787 - d_fake_loss: 0.6770 - d_acc: 0.5663
# Epoch 257/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7467 - d_real_loss: 0.6788 - d_fake_loss: 0.6773 - d_acc: 0.5652
# Epoch 258/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7475 - d_real_loss: 0.6789 - d_fake_loss: 0.6771 - d_acc: 0.5613
# Epoch 259/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7473 - d_real_loss: 0.6783 - d_fake_loss: 0.6768 - d_acc: 0.5639
# Epoch 260/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7484 - d_real_loss: 0.6782 - d_fake_loss: 0.6768 - d_acc: 0.5671
#
# Saving weights at epoch 260
#
# 467/467 [==============================] - 41s 87ms/step - g_loss: 0.7484 - d_real_loss: 0.6782 - d_fake_loss: 0.6768 - d_acc: 0.5671
# Epoch 261/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7482 - d_real_loss: 0.6789 - d_fake_loss: 0.6770 - d_acc: 0.5620
# Epoch 262/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7497 - d_real_loss: 0.6784 - d_fake_loss: 0.6770 - d_acc: 0.5647
# Epoch 263/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7449 - d_real_loss: 0.6780 - d_fake_loss: 0.6766 - d_acc: 0.5682
# Epoch 264/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7475 - d_real_loss: 0.6783 - d_fake_loss: 0.6768 - d_acc: 0.5644
# Epoch 265/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7497 - d_real_loss: 0.6788 - d_fake_loss: 0.6774 - d_acc: 0.5619
# Epoch 266/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7462 - d_real_loss: 0.6781 - d_fake_loss: 0.6763 - d_acc: 0.5630
# Epoch 267/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7473 - d_real_loss: 0.6779 - d_fake_loss: 0.6767 - d_acc: 0.5653
# Epoch 268/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7469 - d_real_loss: 0.6784 - d_fake_loss: 0.6764 - d_acc: 0.5683
# Epoch 269/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7476 - d_real_loss: 0.6785 - d_fake_loss: 0.6772 - d_acc: 0.5679
# Epoch 270/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7470 - d_real_loss: 0.6784 - d_fake_loss: 0.6769 - d_acc: 0.5651
#
# Saving weights at epoch 270
#
# 467/467 [==============================] - 40s 86ms/step - g_loss: 0.7470 - d_real_loss: 0.6784 - d_fake_loss: 0.6769 - d_acc: 0.5651
# Epoch 271/1000
# 467/467 [==============================] - 35s 73ms/step - g_loss: 0.7472 - d_real_loss: 0.6789 - d_fake_loss: 0.6773 - d_acc: 0.5624
# Epoch 272/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7472 - d_real_loss: 0.6781 - d_fake_loss: 0.6764 - d_acc: 0.5680
# Epoch 273/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7465 - d_real_loss: 0.6784 - d_fake_loss: 0.6773 - d_acc: 0.5673
# Epoch 274/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7476 - d_real_loss: 0.6789 - d_fake_loss: 0.6767 - d_acc: 0.5633
# Epoch 275/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7456 - d_real_loss: 0.6777 - d_fake_loss: 0.6767 - d_acc: 0.5678
# Epoch 276/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7469 - d_real_loss: 0.6785 - d_fake_loss: 0.6769 - d_acc: 0.5663
# Epoch 277/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7468 - d_real_loss: 0.6779 - d_fake_loss: 0.6767 - d_acc: 0.5669
# Epoch 278/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7479 - d_real_loss: 0.6780 - d_fake_loss: 0.6766 - d_acc: 0.5680
# Epoch 279/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7454 - d_real_loss: 0.6784 - d_fake_loss: 0.6765 - d_acc: 0.5667
# Epoch 280/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7462 - d_real_loss: 0.6781 - d_fake_loss: 0.6766 - d_acc: 0.5664
#
# Saving weights at epoch 280
#
# 467/467 [==============================] - 40s 85ms/step - g_loss: 0.7462 - d_real_loss: 0.6781 - d_fake_loss: 0.6766 - d_acc: 0.5664
# Epoch 281/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7466 - d_real_loss: 0.6782 - d_fake_loss: 0.6770 - d_acc: 0.5652
# Epoch 282/1000
# 467/467 [==============================] - 36s 77ms/step - g_loss: 0.7463 - d_real_loss: 0.6778 - d_fake_loss: 0.6767 - d_acc: 0.5662
# Epoch 283/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7466 - d_real_loss: 0.6782 - d_fake_loss: 0.6767 - d_acc: 0.5662
# Epoch 284/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7463 - d_real_loss: 0.6783 - d_fake_loss: 0.6768 - d_acc: 0.5684
# Epoch 285/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7475 - d_real_loss: 0.6779 - d_fake_loss: 0.6766 - d_acc: 0.5679
# Epoch 286/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7441 - d_real_loss: 0.6783 - d_fake_loss: 0.6768 - d_acc: 0.5646
# Epoch 287/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7451 - d_real_loss: 0.6785 - d_fake_loss: 0.6771 - d_acc: 0.5652
# Epoch 288/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7466 - d_real_loss: 0.6786 - d_fake_loss: 0.6774 - d_acc: 0.5637
# Epoch 289/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7454 - d_real_loss: 0.6789 - d_fake_loss: 0.6776 - d_acc: 0.5616
# Epoch 290/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7445 - d_real_loss: 0.6780 - d_fake_loss: 0.6768 - d_acc: 0.5670
#
# Saving weights at epoch 290
#
# 467/467 [==============================] - 39s 84ms/step - g_loss: 0.7445 - d_real_loss: 0.6780 - d_fake_loss: 0.6768 - d_acc: 0.5670
# Epoch 291/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7468 - d_real_loss: 0.6787 - d_fake_loss: 0.6771 - d_acc: 0.5651
# Epoch 292/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7454 - d_real_loss: 0.6789 - d_fake_loss: 0.6774 - d_acc: 0.5638
# Epoch 293/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7430 - d_real_loss: 0.6789 - d_fake_loss: 0.6777 - d_acc: 0.5639
# Epoch 294/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7447 - d_real_loss: 0.6789 - d_fake_loss: 0.6775 - d_acc: 0.5634
# Epoch 295/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7445 - d_real_loss: 0.6790 - d_fake_loss: 0.6774 - d_acc: 0.5655
# Epoch 296/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7438 - d_real_loss: 0.6785 - d_fake_loss: 0.6772 - d_acc: 0.5649
# Epoch 297/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7485 - d_real_loss: 0.6789 - d_fake_loss: 0.6779 - d_acc: 0.5643
# Epoch 298/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7442 - d_real_loss: 0.6790 - d_fake_loss: 0.6771 - d_acc: 0.5645
# Epoch 299/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7432 - d_real_loss: 0.6785 - d_fake_loss: 0.6770 - d_acc: 0.5625
# Epoch 300/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7439 - d_real_loss: 0.6788 - d_fake_loss: 0.6772 - d_acc: 0.5640
#
# Saving weights at epoch 300
#
# 467/467 [==============================] - 40s 86ms/step - g_loss: 0.7439 - d_real_loss: 0.6788 - d_fake_loss: 0.6772 - d_acc: 0.5640
# Epoch 301/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7444 - d_real_loss: 0.6791 - d_fake_loss: 0.6776 - d_acc: 0.5622
# Epoch 302/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7443 - d_real_loss: 0.6790 - d_fake_loss: 0.6776 - d_acc: 0.5641
# Epoch 303/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7438 - d_real_loss: 0.6791 - d_fake_loss: 0.6778 - d_acc: 0.5636
# Epoch 304/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7446 - d_real_loss: 0.6790 - d_fake_loss: 0.6776 - d_acc: 0.5656
# Epoch 305/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7438 - d_real_loss: 0.6790 - d_fake_loss: 0.6774 - d_acc: 0.5654
# Epoch 306/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7443 - d_real_loss: 0.6793 - d_fake_loss: 0.6780 - d_acc: 0.5616
# Epoch 307/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7454 - d_real_loss: 0.6787 - d_fake_loss: 0.6775 - d_acc: 0.5666
# Epoch 308/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7448 - d_real_loss: 0.6792 - d_fake_loss: 0.6778 - d_acc: 0.5649
# Epoch 309/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7423 - d_real_loss: 0.6784 - d_fake_loss: 0.6770 - d_acc: 0.5680
# Epoch 310/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7430 - d_real_loss: 0.6791 - d_fake_loss: 0.6775 - d_acc: 0.5627
#
# Saving weights at epoch 310
#
# 467/467 [==============================] - 40s 86ms/step - g_loss: 0.7430 - d_real_loss: 0.6791 - d_fake_loss: 0.6775 - d_acc: 0.5627
# Epoch 311/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7452 - d_real_loss: 0.6793 - d_fake_loss: 0.6782 - d_acc: 0.5620
# Epoch 312/1000
# ...
# Epoch 905/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7125 - d_real_loss: 0.6891 - d_fake_loss: 0.6887 - d_acc: 0.5291
# Epoch 906/1000
# 467/467 [==============================] - 36s 77ms/step - g_loss: 0.7117 - d_real_loss: 0.6889 - d_fake_loss: 0.6885 - d_acc: 0.5311
# Epoch 907/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7117 - d_real_loss: 0.6888 - d_fake_loss: 0.6884 - d_acc: 0.5360
# Epoch 908/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7119 - d_real_loss: 0.6890 - d_fake_loss: 0.6887 - d_acc: 0.5293
# Epoch 909/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7123 - d_real_loss: 0.6889 - d_fake_loss: 0.6885 - d_acc: 0.5336
# Epoch 910/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7121 - d_real_loss: 0.6888 - d_fake_loss: 0.6884 - d_acc: 0.5348
#
# Saving weights at epoch 910
#
# 467/467 [==============================] - 41s 87ms/step - g_loss: 0.7121 - d_real_loss: 0.6888 - d_fake_loss: 0.6884 - d_acc: 0.5348
# Epoch 911/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7112 - d_real_loss: 0.6889 - d_fake_loss: 0.6884 - d_acc: 0.5353
# Epoch 912/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7116 - d_real_loss: 0.6892 - d_fake_loss: 0.6888 - d_acc: 0.5301
# Epoch 913/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7108 - d_real_loss: 0.6890 - d_fake_loss: 0.6888 - d_acc: 0.5312
# Epoch 914/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7111 - d_real_loss: 0.6892 - d_fake_loss: 0.6889 - d_acc: 0.5311
# Epoch 915/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7107 - d_real_loss: 0.6893 - d_fake_loss: 0.6889 - d_acc: 0.5289
# Epoch 916/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7108 - d_real_loss: 0.6896 - d_fake_loss: 0.6891 - d_acc: 0.5298
# Epoch 917/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7101 - d_real_loss: 0.6894 - d_fake_loss: 0.6890 - d_acc: 0.5265
# Epoch 918/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7117 - d_real_loss: 0.6895 - d_fake_loss: 0.6893 - d_acc: 0.5268
# Epoch 919/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7107 - d_real_loss: 0.6892 - d_fake_loss: 0.6889 - d_acc: 0.5314
# Epoch 920/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7098 - d_real_loss: 0.6895 - d_fake_loss: 0.6892 - d_acc: 0.5277
#
# Saving weights at epoch 920
#
# 467/467 [==============================] - 40s 86ms/step - g_loss: 0.7098 - d_real_loss: 0.6895 - d_fake_loss: 0.6892 - d_acc: 0.5277
# Epoch 921/1000
# 467/467 [==============================] - 34s 71ms/step - g_loss: 0.7099 - d_real_loss: 0.6892 - d_fake_loss: 0.6888 - d_acc: 0.5318
# Epoch 922/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7111 - d_real_loss: 0.6894 - d_fake_loss: 0.6890 - d_acc: 0.5275
# Epoch 923/1000
# 467/467 [==============================] - 37s 78ms/step - g_loss: 0.7106 - d_real_loss: 0.6893 - d_fake_loss: 0.6890 - d_acc: 0.5303
# Epoch 924/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7107 - d_real_loss: 0.6892 - d_fake_loss: 0.6887 - d_acc: 0.5270
# Epoch 925/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7111 - d_real_loss: 0.6892 - d_fake_loss: 0.6888 - d_acc: 0.5297
# Epoch 926/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7109 - d_real_loss: 0.6890 - d_fake_loss: 0.6886 - d_acc: 0.5309
# Epoch 927/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7115 - d_real_loss: 0.6890 - d_fake_loss: 0.6886 - d_acc: 0.5312
# Epoch 928/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7108 - d_real_loss: 0.6888 - d_fake_loss: 0.6886 - d_acc: 0.5331
# Epoch 929/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7109 - d_real_loss: 0.6892 - d_fake_loss: 0.6887 - d_acc: 0.5333
# Epoch 930/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7106 - d_real_loss: 0.6887 - d_fake_loss: 0.6883 - d_acc: 0.5334
#
# Saving weights at epoch 930
#
# 467/467 [==============================] - 41s 87ms/step - g_loss: 0.7106 - d_real_loss: 0.6887 - d_fake_loss: 0.6883 - d_acc: 0.5334
# Epoch 931/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7117 - d_real_loss: 0.6888 - d_fake_loss: 0.6884 - d_acc: 0.5328
# Epoch 932/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7112 - d_real_loss: 0.6887 - d_fake_loss: 0.6884 - d_acc: 0.5322
# Epoch 933/1000
# 467/467 [==============================] - 36s 78ms/step - g_loss: 0.7118 - d_real_loss: 0.6888 - d_fake_loss: 0.6884 - d_acc: 0.5326
# Epoch 934/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7106 - d_real_loss: 0.6887 - d_fake_loss: 0.6885 - d_acc: 0.5313
# Epoch 935/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7110 - d_real_loss: 0.6890 - d_fake_loss: 0.6885 - d_acc: 0.5317
# Epoch 936/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7112 - d_real_loss: 0.6887 - d_fake_loss: 0.6885 - d_acc: 0.5350
# Epoch 937/1000
# 467/467 [==============================] - 36s 76ms/step - g_loss: 0.7118 - d_real_loss: 0.6887 - d_fake_loss: 0.6884 - d_acc: 0.5324
# Epoch 938/1000
# 467/467 [==============================] - 36s 76ms/step - g_loss: 0.7109 - d_real_loss: 0.6886 - d_fake_loss: 0.6882 - d_acc: 0.5292
# Epoch 939/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7118 - d_real_loss: 0.6888 - d_fake_loss: 0.6886 - d_acc: 0.5321
# Epoch 940/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7118 - d_real_loss: 0.6888 - d_fake_loss: 0.6885 - d_acc: 0.5306
#
# Saving weights at epoch 940
#
# 467/467 [==============================] - 41s 88ms/step - g_loss: 0.7118 - d_real_loss: 0.6888 - d_fake_loss: 0.6885 - d_acc: 0.5306
# Epoch 941/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7106 - d_real_loss: 0.6888 - d_fake_loss: 0.6883 - d_acc: 0.5283
# Epoch 942/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7117 - d_real_loss: 0.6887 - d_fake_loss: 0.6883 - d_acc: 0.5346
# Epoch 943/1000
# 467/467 [==============================] - 36s 78ms/step - g_loss: 0.7120 - d_real_loss: 0.6888 - d_fake_loss: 0.6884 - d_acc: 0.5355
# Epoch 944/1000
# 467/467 [==============================] - 36s 77ms/step - g_loss: 0.7110 - d_real_loss: 0.6886 - d_fake_loss: 0.6883 - d_acc: 0.5304
# Epoch 945/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7109 - d_real_loss: 0.6887 - d_fake_loss: 0.6881 - d_acc: 0.5301
# Epoch 946/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7109 - d_real_loss: 0.6886 - d_fake_loss: 0.6882 - d_acc: 0.5342
# Epoch 947/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7124 - d_real_loss: 0.6889 - d_fake_loss: 0.6885 - d_acc: 0.5325
# Epoch 948/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7117 - d_real_loss: 0.6886 - d_fake_loss: 0.6882 - d_acc: 0.5329
# Epoch 949/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7114 - d_real_loss: 0.6890 - d_fake_loss: 0.6885 - d_acc: 0.5318
# Epoch 950/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7105 - d_real_loss: 0.6887 - d_fake_loss: 0.6886 - d_acc: 0.5333
#
# Saving weights at epoch 950
#
# 467/467 [==============================] - 40s 86ms/step - g_loss: 0.7105 - d_real_loss: 0.6887 - d_fake_loss: 0.6886 - d_acc: 0.5333
# Epoch 951/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7119 - d_real_loss: 0.6890 - d_fake_loss: 0.6885 - d_acc: 0.5315
# Epoch 952/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7110 - d_real_loss: 0.6886 - d_fake_loss: 0.6883 - d_acc: 0.5341
# Epoch 953/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7115 - d_real_loss: 0.6887 - d_fake_loss: 0.6883 - d_acc: 0.5299
# Epoch 954/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7122 - d_real_loss: 0.6888 - d_fake_loss: 0.6884 - d_acc: 0.5305
# Epoch 955/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7111 - d_real_loss: 0.6889 - d_fake_loss: 0.6886 - d_acc: 0.5317
# Epoch 956/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7120 - d_real_loss: 0.6889 - d_fake_loss: 0.6886 - d_acc: 0.5309
# Epoch 957/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7105 - d_real_loss: 0.6888 - d_fake_loss: 0.6883 - d_acc: 0.5311
# Epoch 958/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7121 - d_real_loss: 0.6887 - d_fake_loss: 0.6885 - d_acc: 0.5318
# Epoch 959/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7112 - d_real_loss: 0.6888 - d_fake_loss: 0.6882 - d_acc: 0.5311
# Epoch 960/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7115 - d_real_loss: 0.6887 - d_fake_loss: 0.6884 - d_acc: 0.5344
#
# Saving weights at epoch 960
#
# 467/467 [==============================] - 41s 87ms/step - g_loss: 0.7115 - d_real_loss: 0.6887 - d_fake_loss: 0.6884 - d_acc: 0.5344
# Epoch 961/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7118 - d_real_loss: 0.6889 - d_fake_loss: 0.6885 - d_acc: 0.5335
# Epoch 962/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7112 - d_real_loss: 0.6891 - d_fake_loss: 0.6888 - d_acc: 0.5278
# Epoch 963/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7121 - d_real_loss: 0.6886 - d_fake_loss: 0.6883 - d_acc: 0.5331
# Epoch 964/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7125 - d_real_loss: 0.6891 - d_fake_loss: 0.6887 - d_acc: 0.5314
# Epoch 965/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7112 - d_real_loss: 0.6888 - d_fake_loss: 0.6885 - d_acc: 0.5353
# Epoch 966/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7110 - d_real_loss: 0.6892 - d_fake_loss: 0.6888 - d_acc: 0.5298
# Epoch 967/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7114 - d_real_loss: 0.6888 - d_fake_loss: 0.6885 - d_acc: 0.5336
# Epoch 968/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7117 - d_real_loss: 0.6888 - d_fake_loss: 0.6887 - d_acc: 0.5323
# Epoch 969/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7122 - d_real_loss: 0.6890 - d_fake_loss: 0.6885 - d_acc: 0.5308
# Epoch 970/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7115 - d_real_loss: 0.6888 - d_fake_loss: 0.6885 - d_acc: 0.5331
#
# Saving weights at epoch 970
#
# 467/467 [==============================] - 88s 189ms/step - g_loss: 0.7115 - d_real_loss: 0.6888 - d_fake_loss: 0.6885 - d_acc: 0.5331
# Epoch 971/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7118 - d_real_loss: 0.6890 - d_fake_loss: 0.6888 - d_acc: 0.5277
# Epoch 972/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7107 - d_real_loss: 0.6889 - d_fake_loss: 0.6884 - d_acc: 0.5298
# Epoch 973/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7112 - d_real_loss: 0.6889 - d_fake_loss: 0.6886 - d_acc: 0.5370
# Epoch 974/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7118 - d_real_loss: 0.6888 - d_fake_loss: 0.6884 - d_acc: 0.5316
# Epoch 975/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7113 - d_real_loss: 0.6890 - d_fake_loss: 0.6887 - d_acc: 0.5348
# Epoch 976/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7100 - d_real_loss: 0.6891 - d_fake_loss: 0.6886 - d_acc: 0.5316
# Epoch 977/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7106 - d_real_loss: 0.6891 - d_fake_loss: 0.6887 - d_acc: 0.5303
# Epoch 978/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7102 - d_real_loss: 0.6890 - d_fake_loss: 0.6886 - d_acc: 0.5326
# Epoch 979/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7113 - d_real_loss: 0.6892 - d_fake_loss: 0.6889 - d_acc: 0.5300
# Epoch 980/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7107 - d_real_loss: 0.6893 - d_fake_loss: 0.6889 - d_acc: 0.5329
#
# Saving weights at epoch 980
#
# 467/467 [==============================] - 40s 86ms/step - g_loss: 0.7107 - d_real_loss: 0.6893 - d_fake_loss: 0.6889 - d_acc: 0.5329
# Epoch 981/1000
# 467/467 [==============================] - 35s 75ms/step - g_loss: 0.7101 - d_real_loss: 0.6892 - d_fake_loss: 0.6890 - d_acc: 0.5276
# Epoch 982/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7110 - d_real_loss: 0.6890 - d_fake_loss: 0.6888 - d_acc: 0.5315
# Epoch 983/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7108 - d_real_loss: 0.6890 - d_fake_loss: 0.6885 - d_acc: 0.5291
# Epoch 984/1000
# 467/467 [==============================] - 35s 74ms/step - g_loss: 0.7097 - d_real_loss: 0.6896 - d_fake_loss: 0.6891 - d_acc: 0.5265
# Epoch 985/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7097 - d_real_loss: 0.6893 - d_fake_loss: 0.6890 - d_acc: 0.5309
# Epoch 986/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7106 - d_real_loss: 0.6896 - d_fake_loss: 0.6892 - d_acc: 0.5298
# Epoch 987/1000
# 467/467 [==============================] - 33s 71ms/step - g_loss: 0.7106 - d_real_loss: 0.6893 - d_fake_loss: 0.6891 - d_acc: 0.5288
# Epoch 988/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7103 - d_real_loss: 0.6896 - d_fake_loss: 0.6892 - d_acc: 0.5269
# Epoch 989/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7102 - d_real_loss: 0.6892 - d_fake_loss: 0.6890 - d_acc: 0.5323
# Epoch 990/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7103 - d_real_loss: 0.6893 - d_fake_loss: 0.6890 - d_acc: 0.5291
#
# Saving weights at epoch 990
#
# 467/467 [==============================] - 40s 85ms/step - g_loss: 0.7103 - d_real_loss: 0.6893 - d_fake_loss: 0.6890 - d_acc: 0.5291
# Epoch 991/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7105 - d_real_loss: 0.6893 - d_fake_loss: 0.6890 - d_acc: 0.5279
# Epoch 992/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7098 - d_real_loss: 0.6892 - d_fake_loss: 0.6889 - d_acc: 0.5313
# Epoch 993/1000
# 467/467 [==============================] - 32s 69ms/step - g_loss: 0.7092 - d_real_loss: 0.6894 - d_fake_loss: 0.6892 - d_acc: 0.5296
# Epoch 994/1000
# 467/467 [==============================] - 34s 74ms/step - g_loss: 0.7100 - d_real_loss: 0.6898 - d_fake_loss: 0.6894 - d_acc: 0.5276
# Epoch 995/1000
# 467/467 [==============================] - 34s 73ms/step - g_loss: 0.7087 - d_real_loss: 0.6893 - d_fake_loss: 0.6890 - d_acc: 0.5266
# Epoch 996/1000
# 467/467 [==============================] - 33s 72ms/step - g_loss: 0.7101 - d_real_loss: 0.6897 - d_fake_loss: 0.6893 - d_acc: 0.5254
# Epoch 997/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7090 - d_real_loss: 0.6896 - d_fake_loss: 0.6892 - d_acc: 0.5291
# Epoch 998/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7100 - d_real_loss: 0.6896 - d_fake_loss: 0.6893 - d_acc: 0.5263
# Epoch 999/1000
# 467/467 [==============================] - 34s 72ms/step - g_loss: 0.7083 - d_real_loss: 0.6896 - d_fake_loss: 0.6894 - d_acc: 0.5259
# Epoch 1000/1000
# 467/467 [==============================] - ETA: 0s - g_loss: 0.7088 - d_real_loss: 0.6899 - d_fake_loss: 0.6894 - d_acc: 0.5256
#
# Saving weights at epoch 1000
#
# 467/467 [==============================] - 40s 85ms/step - g_loss: 0.7088 - d_real_loss: 0.6899 - d_fake_loss: 0.6894 - d_acc: 0.5256
# CPU times: total: 11h 13min 8s
# Wall time: 9h 30min 10s

# %% [markdown]
# ## Model Evaluation

# %%
plt.figure(figsize=(12,6))

plt.plot(history.history['g_loss'], label='gen_loss')
plt.plot(history.history['d_real_loss'], label='disc_real_loss')
plt.plot(history.history['d_fake_loss'], label='disc_fake_loss')

plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(history.history['d_acc'], label='disc_acc')

plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)

plt.show()

# %%
latent_vectors = tf.random.normal(shape=(100, LATENT_DIM))
class_labels = tf.reshape(tf.range(10), shape=(10, 1))
class_labels = tf.tile(class_labels, multiples=(1, 10))
class_labels = tf.reshape(class_labels, shape=(100, 1))

generated_images = cdcgan.generator([latent_vectors, class_labels], training=False)
generated_images = (generated_images + 1) / 2

# %%
fig, axes = plt.subplots(10, 10, figsize=(20, 20))
axes = axes.flatten()

for i, ax in enumerate(axes):
    ax.imshow(generated_images[i], cmap='gray')
    ax.set_title(label_map[class_labels[i].numpy().item()], fontsize=18)
    ax.axis('off')

plt.tight_layout()
plt.show()
